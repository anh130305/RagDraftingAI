# %% [markdown]
# # Hybrid Retrieval Pipeline
# **BM25 + Semantic Search (ChromaDB) + Cross-Encoder Reranker**
#
# Pipeline:
# ```
# Query → [BM25 top-50] ─┐
#                         ├─ Reciprocal Rank Fusion → top-20 → Reranker → top-k
# Query → [Dense  top-50] ┘
# ```
#
# **Chạy local** (CPU, không cần GPU). Reranker sẽ tự dùng GPU nếu có.
#
# Cấu trúc thư mục cần:
# ```
# project/
# ├── dataset/
# │   ├── chunks/
# │   │   ├── legal_chunks.parquet
# │   │   ├── forms_chunks.parquet
# │   │   └── examples_chunks.parquet
# │   ├── chromadb/          ← giải nén từ chromadb_output.zip
# │   └── bm25/              ← tự tạo khi chạy notebook này
# │       ├── bm25_legal.pkl
# │       ├── bm25_forms.pkl
# │       └── bm25_examples.pkl
# └── models/
#     ├── embedding/         ← cache multilingual-e5-large-instruct
#     └── reranker/          ← cache bge-reranker-v2-m3
# ```

# %% [markdown]
# ## 0. Cài đặt thư viện

# %%
# Chạy cell này lần đầu
# !pip3 install rank-bm25 sentence-transformers chromadb underthesea unicodedata2 tqdm pandas pyarrow

# %% [markdown]
# ## 1. Imports & Config

# %%
import os
import re
import json
import time
import pickle
import unicodedata
from pathlib import Path
from typing import List, Dict, Optional, Tuple

import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import torch
import chromadb
from chromadb.config import Settings
from rank_bm25 import BM25Okapi
from sentence_transformers import SentenceTransformer, CrossEncoder

print("Imports OK")
print(f"PyTorch  : {torch.__version__}")
print(f"Device   : {'cuda' if torch.cuda.is_available() else 'cpu'}")
# Out:
# Imports OK
# PyTorch  : 2.9.1+cu126
# Device   : cuda

# %%
# ============================================================
# CONFIG — chỉnh sửa paths nếu khác cấu trúc thư mục
# ============================================================

PROJECT_ROOT   = Path(".")                          # thư mục gốc project
CHUNK_DIR      = PROJECT_ROOT / "dataset" / "chunks"
CHROMA_DIR     = PROJECT_ROOT / "dataset" / "chromadb"
BM25_DIR       = PROJECT_ROOT / "dataset" / "bm25"
MODEL_EMBED    = PROJECT_ROOT / "models" / "embedding"
MODEL_RERANK   = PROJECT_ROOT / "models" / "reranker"

EMBED_MODEL_NAME  = "intfloat/multilingual-e5-large-instruct"
RERANK_MODEL_NAME = "BAAI/bge-reranker-v2-m3"       # multilingual, hỗ trợ tiếng Việt tốt

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# Retrieval params
BM25_TOP_K    = 50   # BM25 candidates
DENSE_TOP_K   = 50   # ChromaDB candidates
RRF_K         = 60   # Reciprocal Rank Fusion constant
RERANK_TOP_N  = 20   # Số candidates đưa vào reranker
FINAL_TOP_K   = 5    # Kết quả cuối

# Embedding instructions (asymmetric retrieval)
INSTRUCTIONS = {
    "legal"   : "Instruct: Tim dieu khoan phap luat Viet Nam lien quan.\nQuery: ",
    "forms"   : "Instruct: Tim mau bieu hanh chinh phu hop voi nhu cau soan thao.\nQuery: ",
    "examples": "Instruct: Tim vi du van ban hanh chinh tuong tu tinh huong sau.\nQuery: ",
}

# Tạo thư mục
BM25_DIR.mkdir(parents=True, exist_ok=True)
MODEL_EMBED.mkdir(parents=True, exist_ok=True)
MODEL_RERANK.mkdir(parents=True, exist_ok=True)

# Sanity checks
for name, path in {
    "legal_chunks"   : CHUNK_DIR / "legal_chunks.parquet",
    "forms_chunks"   : CHUNK_DIR / "forms_chunks.parquet",
    "examples_chunks": CHUNK_DIR / "examples_chunks.parquet",
    "chromadb"       : CHROMA_DIR,
}.items():
    status = "✅" if path.exists() else "❌ NOT FOUND"
    print(f"  {status} {name}: {path}")
# Out:
#   ✅ legal_chunks: dataset/chunks/legal_chunks.parquet
#   ✅ forms_chunks: dataset/chunks/forms_chunks.parquet
#   ✅ examples_chunks: dataset/chunks/examples_chunks.parquet
#   ✅ chromadb: dataset/chromadb

# %% [markdown]
# ## 2. Text Normalization Utilities

# %%
def remove_diacritics(text: str) -> str:
    """Bỏ dấu tiếng Việt: dùng cho BM25 tokenization.
    Cả corpus lẫn query đều được normalize → đảm bảo match dù user gõ có/không dấu.
    """
    # Chuyển sang NFD (tách base char + combining marks)
    nfd = unicodedata.normalize("NFD", text)
    # Loại combining diacritical marks (category Mn)
    stripped = "".join(c for c in nfd if unicodedata.category(c) != "Mn")
    # Xử lý đ/Đ (không phải diacritics mà là ký tự riêng)
    stripped = stripped.replace("đ", "d").replace("Đ", "D")
    return stripped


def normalize_text(text: str) -> str:
    """Clean whitespace, lowercase."""
    text = str(text).lower().strip()
    text = re.sub(r"\s+", " ", text)
    return text


def tokenize_for_bm25(text: str) -> List[str]:
    """Tokenize text cho BM25: lowercase → bỏ dấu → tách word."""
    text = normalize_text(text)
    text = remove_diacritics(text)
    # Tách theo space + loại token rỗng, số, ký tự đặc biệt ngắn
    tokens = re.findall(r"[a-z][a-z0-9]{1,}", text)  # ít nhất 2 ký tự
    return tokens


# Quick test
test_cases = [
    "Quy định về hòa giải ở cơ sở",
    "quy dinh ve hoa giai o co so",      # không dấu
    "điều kiện để được cấp giấy phép kinh doanh",
    "dieu kien de duoc cap giay phep kinh doanh",
]
print("Tokenization test:")
for t in test_cases:
    tokens = tokenize_for_bm25(t)
    print(f"  Input : {t[:60]}")
    print(f"  Tokens: {tokens[:10]}")
    print()
# Out:
# Tokenization test:
#   Input : Quy định về hòa giải ở cơ sở
#   Tokens: ['quy', 'dinh', 've', 'hoa', 'giai', 'co', 'so']
#
#   Input : quy dinh ve hoa giai o co so
#   Tokens: ['quy', 'dinh', 've', 'hoa', 'giai', 'co', 'so']
#
#   Input : điều kiện để được cấp giấy phép kinh doanh
#   Tokens: ['dieu', 'kien', 'de', 'duoc', 'cap', 'giay', 'phep', 'kinh', 'doanh']
#
#   Input : dieu kien de duoc cap giay phep kinh doanh
#   Tokens: ['dieu', 'kien', 'de', 'duoc', 'cap', 'giay', 'phep', 'kinh', 'doanh']

# %% [markdown]
# ## 3. Build & Persist BM25 Indexes

# %%
def build_bm25_index(
    df: pd.DataFrame,
    text_col: str,
    save_path: Path,
    name: str,
    force_rebuild: bool = False,
) -> Tuple[BM25Okapi, List[str]]:
    """
    Build BM25 index từ DataFrame, persist bằng pickle.
    Nếu file đã tồn tại và force_rebuild=False → load từ disk.
    
    Returns: (bm25_index, chunk_ids)
    """
    meta_path = save_path.with_suffix(".meta.pkl")

    if save_path.exists() and meta_path.exists() and not force_rebuild:
        print(f"[{name}] Loading BM25 index from cache: {save_path}")
        t0 = time.time()
        with open(save_path, "rb") as f:
            bm25 = pickle.load(f)
        with open(meta_path, "rb") as f:
            meta = pickle.load(f)
        print(f"  Loaded {len(meta['chunk_ids']):,} docs in {time.time()-t0:.1f}s")
        return bm25, meta["chunk_ids"]

    print(f"[{name}] Building BM25 index ({len(df):,} docs)...")
    t0 = time.time()

    chunk_ids = df["chunk_id"].tolist()
    corpus_tokens = [
        tokenize_for_bm25(text)
        for text in tqdm(df[text_col], desc=f"  Tokenizing {name}", leave=False)
    ]

    print(f"  Tokenized in {time.time()-t0:.1f}s, building BM25...")
    t1 = time.time()
    bm25 = BM25Okapi(corpus_tokens)
    print(f"  BM25 built in {time.time()-t1:.1f}s")

    # Persist
    with open(save_path, "wb") as f:
        pickle.dump(bm25, f, protocol=pickle.HIGHEST_PROTOCOL)
    with open(meta_path, "wb") as f:
        pickle.dump({"chunk_ids": chunk_ids}, f, protocol=pickle.HIGHEST_PROTOCOL)

    size_mb = save_path.stat().st_size / 1024 / 1024
    print(f"  Saved to {save_path} ({size_mb:.1f} MB) | Total: {time.time()-t0:.1f}s")
    return bm25, chunk_ids


print("BM25 builder defined.")
# Out:
# BM25 builder defined.

# %%
# ============================================================
# Load parquet files & build BM25 indexes
# ============================================================

FORCE_REBUILD = False   # True để rebuild dù đã có cache

print("Loading chunk files...")
df_legal    = pd.read_parquet(CHUNK_DIR / "legal_chunks.parquet")
df_forms    = pd.read_parquet(CHUNK_DIR / "forms_chunks.parquet")
df_examples = pd.read_parquet(CHUNK_DIR / "examples_chunks.parquet")

print(f"  legal    : {len(df_legal):,} chunks")
print(f"  forms    : {len(df_forms):,} chunks")
print(f"  examples : {len(df_examples):,} chunks")
print()

# Build / load BM25 indexes
bm25_legal, ids_legal = build_bm25_index(
    df_legal, "text",
    BM25_DIR / "bm25_legal.pkl",
    "legal", force_rebuild=FORCE_REBUILD
)

bm25_forms, ids_forms = build_bm25_index(
    df_forms, "text",
    BM25_DIR / "bm25_forms.pkl",
    "forms", force_rebuild=FORCE_REBUILD
)

bm25_examples, ids_examples = build_bm25_index(
    df_examples, "text",
    BM25_DIR / "bm25_examples.pkl",
    "examples", force_rebuild=FORCE_REBUILD
)

print("\n✅ All BM25 indexes ready.")

# Build lookup: chunk_id → row metadata (for result display)
legal_meta    = df_legal.set_index("chunk_id").to_dict(orient="index")
forms_meta    = df_forms.set_index("chunk_id").to_dict(orient="index")
examples_meta = df_examples.set_index("chunk_id").to_dict(orient="index")

print("Metadata lookups built.")
# Out:
# Loading chunk files...
#   legal    : 237,918 chunks
#   forms    : 10 chunks
#   examples : 150 chunks
#
# [legal] Loading BM25 index from cache: dataset/bm25/bm25_legal.pkl
#   Loaded 237,918 docs in 3.2s
# [forms] Loading BM25 index from cache: dataset/bm25/bm25_forms.pkl
#   Loaded 10 docs in 0.0s
# [examples] Loading BM25 index from cache: dataset/bm25/bm25_examples.pkl
#   Loaded 150 docs in 0.0s
#
# ✅ All BM25 indexes ready.
# Metadata lookups built.

# %% [markdown]
# ## 4. Load Embedding Model & ChromaDB

# %%
print(f"Loading embedding model: {EMBED_MODEL_NAME}")
print("(~1.1 GB, sẽ cache sau lần đầu)")
t0 = time.time()

embed_model = SentenceTransformer(
    EMBED_MODEL_NAME,
    device=DEVICE,
    cache_folder=str(MODEL_EMBED),
)
try:
    EMBED_DIM = embed_model.get_embedding_dimension()
except AttributeError:
    EMBED_DIM = embed_model.get_sentence_embedding_dimension()
print(f"✅ Loaded in {time.time()-t0:.1f}s | dim={EMBED_DIM} | device={DEVICE}")
# Out:
# Loading embedding model: intfloat/multilingual-e5-large-instruct
# (~1.1 GB, sẽ cache sau lần đầu)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# ✅ Loaded in 12.5s | dim=1024 | device=cuda

# %%
print(f"Connecting to ChromaDB: {CHROMA_DIR}")

chroma_client = chromadb.PersistentClient(
    path=str(CHROMA_DIR),
    settings=Settings(anonymized_telemetry=False),
)

col_legal    = chroma_client.get_collection("legal_chunks")
col_forms    = chroma_client.get_collection("forms_chunks")
col_examples = chroma_client.get_collection("examples_chunks")

print(f"✅ Collections loaded:")
print(f"   legal    : {col_legal.count():,}")
print(f"   forms    : {col_forms.count():,}")
print(f"   examples : {col_examples.count():,}")
# Out:
# Connecting to ChromaDB: dataset/chromadb
# ✅ Collections loaded:
#    legal    : 237,918
#    forms    : 10
#    examples : 150

# %% [markdown]
# ## 5. Load Reranker

# %%
print(f"Loading reranker: {RERANK_MODEL_NAME}")
print("(~1.1 GB, multilingual — hỗ trợ tiếng Việt)")
t0 = time.time()

reranker = CrossEncoder(
    RERANK_MODEL_NAME,
    device=DEVICE,
    cache_folder=str(MODEL_RERANK),
    max_length=512,
)
print(f"✅ Reranker loaded in {time.time()-t0:.1f}s")
# Out:
# Loading reranker: BAAI/bge-reranker-v2-m3
# (~1.1 GB, multilingual — hỗ trợ tiếng Việt)
# The Transformer `cache_dir` argument is deprecated. Please pass `cache_dir` via `model_kwargs`, `processor_kwargs`, and/or `config_kwargs` instead.
# Loading weights:   0%|          | 0/393 [00:00<?, ?it/s]
# ✅ Reranker loaded in 9.1s

# %% [markdown]
# ## 6. Hybrid Retriever Class

# %%
class HybridRetriever:
    """
    Hybrid retrieval: BM25 (sparse) + ChromaDB (dense) → RRF → Cross-Encoder Reranker.
    
    Hỗ trợ cả query có dấu lẫn không dấu:
    - BM25  : normalize về không dấu → match keyword
    - Dense : dùng text gốc (embedding model tự handle)
    """

    def __init__(
        self,
        bm25_index: BM25Okapi,
        bm25_ids: List[str],
        chroma_col,
        meta_lookup: Dict,
        embed_model: SentenceTransformer,
        reranker: CrossEncoder,
        instruction: str,
        collection_name: str,
        bm25_top_k: int = BM25_TOP_K,
        dense_top_k: int = DENSE_TOP_K,
        rrf_k: int = RRF_K,
        rerank_top_n: int = RERANK_TOP_N,
        final_top_k: int = FINAL_TOP_K,
    ):
        self.bm25        = bm25_index
        self.bm25_ids    = bm25_ids
        self.col         = chroma_col
        self.meta        = meta_lookup
        self.embed_model = embed_model
        self.reranker    = reranker
        self.instruction = instruction
        self.name        = collection_name
        self.bm25_top_k  = bm25_top_k
        self.dense_top_k = dense_top_k
        self.rrf_k       = rrf_k
        self.rerank_top_n = rerank_top_n
        self.final_top_k = final_top_k

    # ----------------------------------------------------------
    # BM25 search
    # ----------------------------------------------------------
    def _bm25_search(self, query: str) -> List[Tuple[str, float]]:
        """Returns list of (chunk_id, bm25_score), sorted desc."""
        tokens = tokenize_for_bm25(query)
        if not tokens:
            return []
        scores = self.bm25.get_scores(tokens)
        top_idx = np.argsort(scores)[::-1][: self.bm25_top_k]
        # Lọc score = 0 (không có overlap)
        return [
            (self.bm25_ids[i], float(scores[i]))
            for i in top_idx
            if scores[i] > 0
        ]

    # ----------------------------------------------------------
    # Dense (ChromaDB) search
    # ----------------------------------------------------------
    def _dense_search(
        self, query: str, where: Optional[Dict] = None
    ) -> List[Tuple[str, float, str, Dict]]:
        """Returns list of (chunk_id, distance, document_text, metadata_dict), sorted asc distance.
        FIX: include metadatas trong query để lấy metadata trực tiếp từ ChromaDB,
        tránh lookup qua chunk_id (SHA-256 vs text-key không khớp).
        """
        # Asymmetric query encoding
        q_text = self.instruction + query
        q_vec  = self.embed_model.encode(
            [q_text],
            normalize_embeddings=True,
            convert_to_numpy=True,
            show_progress_bar=False,
        )[0]

        kwargs = dict(
            query_embeddings=[q_vec.tolist()],
            n_results=self.dense_top_k,
            include=["documents", "metadatas", "distances"],  # FIX: thêm metadatas
        )
        if where:
            kwargs["where"] = where

        res = self.col.query(**kwargs)
        results = []
        for cid, dist, doc, meta in zip(
            res["ids"][0], res["distances"][0], res["documents"][0], res["metadatas"][0]  # FIX
        ):
            results.append((cid, float(dist), doc, meta or {}))
        return results   # sorted by dist asc (best first)

    # ----------------------------------------------------------
    # Reciprocal Rank Fusion
    # ----------------------------------------------------------
    def _rrf(
        self,
        bm25_results: List[Tuple[str, float]],
        dense_results: List[Tuple[str, float, str, Dict]],
    ) -> List[Tuple[str, float]]:
        """
        Merge hai ranked list bằng RRF.
        Returns list of (chunk_id, rrf_score) sorted desc.
        """
        scores: Dict[str, float] = {}

        for rank, (cid, _) in enumerate(bm25_results, start=1):
            scores[cid] = scores.get(cid, 0.0) + 1.0 / (self.rrf_k + rank)

        for rank, (cid, _, _, _) in enumerate(dense_results, start=1):  # FIX: unpack 4
            scores[cid] = scores.get(cid, 0.0) + 1.0 / (self.rrf_k + rank)

        return sorted(scores.items(), key=lambda x: x[1], reverse=True)

    # ----------------------------------------------------------
    # Cross-Encoder Reranker
    # ----------------------------------------------------------
    def _rerank(
        self,
        query: str,
        candidate_ids: List[str],
        doc_texts: Dict[str, str],
    ) -> List[Tuple[str, float]]:
        """
        Rerank top-N candidates với cross-encoder.
        Returns list of (chunk_id, rerank_score) sorted desc.
        """
        pairs = [(query, doc_texts[cid]) for cid in candidate_ids if cid in doc_texts]
        if not pairs:
            return [(cid, 0.0) for cid in candidate_ids]

        rerank_scores = self.reranker.predict(pairs, show_progress_bar=False)
        ranked = sorted(
            zip(candidate_ids[: len(pairs)], rerank_scores.tolist()),
            key=lambda x: x[1],
            reverse=True,
        )
        return ranked

    # ----------------------------------------------------------
    # Public API
    # ----------------------------------------------------------
    def retrieve(
        self,
        query: str,
        where: Optional[Dict] = None,
        use_reranker: bool = True,
        return_scores: bool = False,
    ) -> List[Dict]:
        """
        Full hybrid retrieval pipeline.

        Args:
            query        : User query (có dấu hoặc không dấu đều OK)
            where        : ChromaDB metadata filter (VD: {"type_normalized": "NGHỊ ĐỊNH"})
            use_reranker : False để bỏ qua reranker (nhanh hơn)
            return_scores: True để trả về dict đầy đủ scores

        Returns:
            List[Dict] với final_top_k kết quả, mỗi dict có:
              chunk_id, text, metadata, bm25_score, dense_dist, rrf_score, rerank_score
        """
        t0 = time.time()

        # 1. BM25 search
        bm25_res  = self._bm25_search(query)

        # 2. Dense search
        dense_res = self._dense_search(query, where=where)

        # 3. Build doc text & metadata lookups
        doc_texts:   Dict[str, str]  = {}
        chroma_meta: Dict[str, Dict] = {}
        for cid, _, doc, meta in dense_res:  # FIX: unpack metadata từ ChromaDB
            doc_texts[cid]   = doc
            chroma_meta[cid] = meta
        # BM25-only hits: fallback lấy text & metadata từ parquet meta_lookup
        for cid, _ in bm25_res:
            if cid not in doc_texts and cid in self.meta:
                doc_texts[cid]   = self.meta[cid].get("text", "")
                chroma_meta[cid] = self.meta[cid]  # FIX: parquet row làm fallback metadata

        # Score lookups
        bm25_score_map  = {cid: s for cid, s in bm25_res}
        dense_dist_map  = {cid: d for cid, d, _, _ in dense_res}  # FIX: unpack 4

        # 4. RRF merge
        rrf_ranked = self._rrf(bm25_res, dense_res)

        # 5. Take top-N for reranker
        top_n_ids = [cid for cid, _ in rrf_ranked[: self.rerank_top_n]]
        rrf_score_map = {cid: s for cid, s in rrf_ranked}

        # 6. Rerank
        if use_reranker and top_n_ids:
            final_ranked = self._rerank(query, top_n_ids, doc_texts)
        else:
            final_ranked = [(cid, rrf_score_map.get(cid, 0.0)) for cid in top_n_ids]

        # 7. Build output
        results = []
        for cid, rerank_score in final_ranked[: self.final_top_k]:
            meta = chroma_meta.get(cid, {})  # FIX: dùng ChromaDB metadata
            results.append({
                "chunk_id"     : cid,
                "text"         : doc_texts.get(cid, ""),
                "metadata"     : meta,
                "bm25_score"   : round(bm25_score_map.get(cid, 0.0), 4),
                "dense_dist"   : round(dense_dist_map.get(cid, 1.0), 4),
                "rrf_score"    : round(rrf_score_map.get(cid, 0.0), 6),
                "rerank_score" : round(float(rerank_score), 4),
                "latency_ms"   : round((time.time() - t0) * 1000, 1),
            })

        return results

    def retrieve_only_semantic(
        self,
        query: str,
        where: Optional[Dict] = None,
    ) -> List[Dict]:
        """Chỉ dùng ChromaDB (để so sánh baseline)."""
        dense_res = self._dense_search(query, where=where)
        results = []
        for cid, dist, doc, meta in dense_res[: self.final_top_k]:  # FIX: unpack metadata
            results.append({
                "chunk_id"  : cid,
                "text"      : doc,
                "metadata"  : meta,  # FIX: metadata từ ChromaDB
                "dense_dist": round(dist, 4),
            })
        return results


print("HybridRetriever class defined.")
# Out:
# HybridRetriever class defined.

# %% [markdown]
# ## 7. Khởi tạo Retrievers

# %%
retriever_legal = HybridRetriever(
    bm25_index      = bm25_legal,
    bm25_ids        = ids_legal,
    chroma_col      = col_legal,
    meta_lookup     = legal_meta,
    embed_model     = embed_model,
    reranker        = reranker,
    instruction     = INSTRUCTIONS["legal"],
    collection_name = "legal",
)

retriever_forms = HybridRetriever(
    bm25_index      = bm25_forms,
    bm25_ids        = ids_forms,
    chroma_col      = col_forms,
    meta_lookup     = forms_meta,
    embed_model     = embed_model,
    reranker        = reranker,
    instruction     = INSTRUCTIONS["forms"],
    collection_name = "forms",
    final_top_k     = 3,
)

retriever_examples = HybridRetriever(
    bm25_index      = bm25_examples,
    bm25_ids        = ids_examples,
    chroma_col      = col_examples,
    meta_lookup     = examples_meta,
    embed_model     = embed_model,
    reranker        = reranker,
    instruction     = INSTRUCTIONS["examples"],
    collection_name = "examples",
    final_top_k     = 3,
)

print("✅ All retrievers ready.")
# Out:
# ✅ All retrievers ready.

# %% [markdown]
# ## 8. Display Helper

# %%
def print_legal_results(results: List[Dict], query: str, mode: str = "hybrid"):
    print(f"\n{'='*70}")
    print(f"[{mode.upper()}] Query: {query}")
    print(f"{'='*70}")
    for i, r in enumerate(results, 1):
        meta = r["metadata"]
        doc_no   = meta.get("source_doc_no", meta.get("id", "?"))
        article  = meta.get("article", "")
        doc_type = meta.get("type_normalized", "")
        text_preview = r["text"][:200].replace("\n", " ")
        score_str = (
            f"rerank={r.get('rerank_score','N/A'):.4f} | "
            f"rrf={r.get('rrf_score',0):.5f} | "
            f"bm25={r.get('bm25_score',0):.2f} | "
            f"dense_dist={r.get('dense_dist',1):.4f}"
        ) if "rerank_score" in r else f"dense_dist={r.get('dense_dist',1):.4f}"

        print(f"\n  [{i}] {doc_no} | {doc_type}")
        print(f"      📌 {article}")
        print(f"      🎯 {score_str}")
        print(f"      📝 {text_preview}...")
    latency = results[0].get("latency_ms", 0) if results else 0
    print(f"\n  ⏱  Latency: {latency}ms")


def print_forms_results(results: List[Dict], query: str, mode: str = "hybrid"):
    print(f"\n{'='*70}")
    print(f"[{mode.upper()} - FORMS] Query: {query}")
    print(f"{'='*70}")
    for i, r in enumerate(results, 1):
        meta = r["metadata"]
        form_id   = meta.get("form_id", "?")
        form_type = meta.get("form_type", "")
        purpose   = meta.get("purpose", "")
        score_str = f"rerank={r.get('rerank_score',0):.4f}" if "rerank_score" in r else f"dist={r.get('dense_dist',1):.4f}"
        print(f"  [{i}] {form_id} | {form_type} | {score_str}")
        print(f"      Purpose: {purpose[:200]}")


def print_examples_results(results: List[Dict], query: str, mode: str = "hybrid"):
    print(f"\n{'='*70}")
    print(f"[{mode.upper()} - EXAMPLES] Query: {query}")
    print(f"{'='*70}")
    for i, r in enumerate(results, 1):
        meta = r["metadata"]
        form_id  = meta.get("form_id", "?")
        scenario = meta.get("scenario", "")
        text_preview = r["text"][:150].replace("\n", " ")
        score_str = f"rerank={r.get('rerank_score',0):.4f}" if "rerank_score" in r else f"dist={r.get('dense_dist',1):.4f}"
        print(f"  [{i}] {form_id} | {score_str}")
        print(f"      Scenario: {scenario[:200]}")
        print(f"      Preview : {text_preview}...")


print("Display helpers defined.")
# Out:
# Display helpers defined.

# %% [markdown]
# ## 9. Test Queries — Legal Retrieval

# %%
# ============================================================
# TEST LEGAL — Query đa dạng: có dấu, không dấu, câu hỏi tự nhiên
# ============================================================

test_legal_queries = [
    # Trường hợp từ context (baseline đã test)
    "quy dinh ve hoa giai o co so",
    "dieu kien de duoc cap giay phep kinh doanh",
    "trach nhiem cua Bo truong trong ban hanh van ban",

    # Có dấu
    "Quy định về hòa giải ở cơ sở",
    "Điều kiện thành lập doanh nghiệp",
    "Quyền và nghĩa vụ của người lao động",

    # Câu hỏi tự nhiên
    "thủ tục xin cấp phép xây dựng nhà ở",
    "xử phạt vi phạm hành chính trong lĩnh vực giao thông",
    "quy trình bổ nhiệm cán bộ công chức",
    "bảo hiểm xã hội bắt buộc cho người lao động",
]

for query in test_legal_queries:
    # Hybrid
    results_hybrid = retriever_legal.retrieve(query, use_reranker=True)
    print_legal_results(results_hybrid, query, mode="hybrid")

    # Baseline: semantic only (để so sánh)
    results_semantic = retriever_legal.retrieve_only_semantic(query)
    print_legal_results(results_semantic, query, mode="semantic-only")
    print("\n" + "-"*70)
# Out:
# ======================================================================
# [HYBRID] Query: quy dinh ve hoa giai o co so
# ======================================================================
#
#   [1] 18/2022/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 22. Lễ đặt vòng hoa tại Đài tưởng niệm các anh hùng liệt sỹ, Lễ đặt vòng hoa và vào Lăng viếng Chủ tịch Hồ Chí Minh
#       🎯 rerank=0.0058 | rrf=0.01639 | bm25=0.00 | dense_dist=0.1135
#       📝 Điều 22. Lễ đặt vòng hoa tại Đài tưởng niệm các anh hùng liệt sỹ, Lễ đặt vòng hoa và vào Lăng viếng Chủ tịch Hồ Chí Minh 1. Lễ đặt vòng hoa tại Đài tưởng niệm và Lễ đặt vòng hoa, vào Lăng viếng Chủ tị...
#
#   [2] 01/2023/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 2. Nhiệm vụ và quyền hạn
#       🎯 rerank=0.0053 | rrf=0.01587 | bm25=0.00 | dense_dist=0.1143
#       📝 [Điều 2. Nhiệm vụ và quyền hạn] Bộ Quốc phòng, Bộ Công an và Ủy ban nhân dân tỉnh, thành phố trực thuộc trung ương tổ chức hội thi bắn pháo hoa quốc tế tại Việt Nam sau khi được Thủ tướng Chính phủ ch...
#
#   [3] 12/2019/NQ-HĐND | NGHỊ QUYẾT
#       📌 Điều 1.
#       🎯 rerank=0.0040 | rrf=0.01515 | bm25=0.00 | dense_dist=0.1162
#       📝 Điều 1. (có Quy định chi tiết kèm theo)...
#
#   [4] 63/2016/NQ-HĐND | NGHỊ QUYẾT
#       📌 Điều 6. Giáo dục, y tế, văn hóa, xã hội
#       🎯 rerank=0.0020 | rrf=0.01449 | bm25=0.00 | dense_dist=0.1174
#       📝 [Điều 6. Giáo dục, y tế, văn hóa, xã hội] đúng Luật Hôn nhân và gia đình, phù hợp với phong tục tập quán của dân tộc, của địa phương. Không vi phạm các điều cấm của Luật Hôn nhân và gia đình. b) Không...
#
#   [5] 126/2014/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 67. Trách nhiệm thi hành
#       🎯 rerank=0.0019 | rrf=0.01429 | bm25=0.00 | dense_dist=0.1176
#       📝 [Điều 67. Trách nhiệm thi hành] Các Bộ trưởng, Thủ trưởng cơ quan ngang Bộ, Thủ trưởng cơ quan thuộc Chính phủ, Chủ tịch Ủy ban nhân dân các cấp và các tổ chức, cá nhân có liên quan chịu trách nhiệm t...
#
#   ⏱  Latency: 5052.0ms
#
# ======================================================================
# [SEMANTIC-ONLY] Query: quy dinh ve hoa giai o co so
# ======================================================================
#
#   [1] 18/2022/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 22. Lễ đặt vòng hoa tại Đài tưởng niệm các anh hùng liệt sỹ, Lễ đặt vòng hoa và vào Lăng viếng Chủ tịch Hồ Chí Minh
#       🎯 dense_dist=0.1135
#       📝 Điều 22. Lễ đặt vòng hoa tại Đài tưởng niệm các anh hùng liệt sỹ, Lễ đặt vòng hoa và vào Lăng viếng Chủ tịch Hồ Chí Minh 1. Lễ đặt vòng hoa tại Đài tưởng niệm và Lễ đặt vòng hoa, vào Lăng viếng Chủ tị...
#
#   [2] 17/NQ-HĐND | NGHỊ QUYẾT
#       📌 Điều 1.
#       🎯 dense_dist=0.1143
#       📝 Điều 1. (Chi tiết tại các phụ lục I, II, III, IV, V, VI, VII, VIII đính kèm)...
#
#   [3] 01/2023/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 2. Nhiệm vụ và quyền hạn
#       🎯 dense_dist=0.1143
#       📝 [Điều 2. Nhiệm vụ và quyền hạn] Bộ Quốc phòng, Bộ Công an và Ủy ban nhân dân tỉnh, thành phố trực thuộc trung ương tổ chức hội thi bắn pháo hoa quốc tế tại Việt Nam sau khi được Thủ tướng Chính phủ ch...
#
#   [4] 17/NQ-HĐND | NGHỊ QUYẾT
#       📌 Điều 1.
#       🎯 dense_dist=0.1144
#       📝 Điều 1. (Chi tiết tại Biểu kèm theo)...
#
#   [5] 14/NQ-HĐND | NGHỊ QUYẾT
#       📌 Điều 1.
#       🎯 dense_dist=0.1159
#       📝 Điều 1. (Chi tiết tại các phụ lục kèm theo)...
#
#   ⏱  Latency: 0ms
#
# ----------------------------------------------------------------------
#
# ======================================================================
# [HYBRID] Query: dieu kien de duoc cap giay phep kinh doanh
# ======================================================================
#
#   [1] 81/2016/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 1. Sửa đổi, bổ sung một số Điều của Nghị định số 25/2011/NĐ-CP ngày 06 tháng 4 năm 2011 của Chính phủ quy định chi Tiết và hướng dẫn thi hành một số Điều của Luật viễn thông (Nghị định số 25/2011/NĐ-CP)
#       🎯 rerank=0.4876 | rrf=0.01538 | bm25=24.78 | dense_dist=1.0000
#       📝 [Điều 1. Sửa đổi, bổ sung một số Điều của Nghị định số 25/2011/NĐ-CP ngày 06 tháng 4 năm 2011 của Chính phủ quy định chi Tiết và hướng dẫn thi hành một số Điều của Luật viễn thông (Nghị định số 25/201...
#
#   [2] 121/2021/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 30. Thủ tục cấp lại, điều chỉnh, gia hạn Giấy phép
#       🎯 rerank=0.4711 | rrf=0.01429 | bm25=24.28 | dense_dist=1.0000
#       📝 [Điều 30. Thủ tục cấp lại, điều chỉnh, gia hạn Giấy phép] 1. Cấp lại Giấy phép a) Doanh nghiệp phải làm thủ tục cấp lại Giấy phép trong các trường hợp sau: - Giấy phép bị mất, thất lạc, hư hỏng do thi...
#
#   [3] 54/2019/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 16. Thu hồi Giấy phép đủ điều kiện kinh doanh
#       🎯 rerank=0.4542 | rrf=0.01515 | bm25=24.72 | dense_dist=1.0000
#       📝 Điều 16. Thu hồi Giấy phép đủ điều kiện kinh doanh 1. Cơ quan cấp Giấy phép đủ điều kiện kinh doanh ban hành Quyết định thu hồi Giấy phép đủ điều kiện kinh doanh khi doanh nghiệp, hộ kinh doanh thuộc ...
#
#   [4] 72/2006/QH11 | LUẬT
#       📌 Điều 11. Đổi Giấy phép
#       🎯 rerank=0.3915 | rrf=0.01613 | bm25=25.66 | dense_dist=1.0000
#       📝 [Điều 11. Đổi Giấy phép] 1. Doanh nghiệp dịch vụ được đổi Giấy phép khi được cấp lại Giấy chứng nhận đăng ký kinh doanh do thay đổi nội dung đăng ký kinh doanh nếu có đủ điều kiện về vốn pháp định quy...
#
#   [5] 113/2017/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 15. Điều kiện cấp Giấy phép sản xuất, kinh doanh hóa chất hạn chế sản xuất, kinh doanh trong lĩnh vực công nghiệp
#       🎯 rerank=0.3771 | rrf=0.01449 | bm25=24.35 | dense_dist=1.0000
#       📝 Điều 15. Điều kiện cấp Giấy phép sản xuất, kinh doanh hóa chất hạn chế sản xuất, kinh doanh trong lĩnh vực công nghiệp 1. Điều kiện cấp Giấy phép sản xuất hóa chất hạn chế sản xuất, kinh doanh trong l...
#
#   ⏱  Latency: 3590.5ms
#
# ======================================================================
# [SEMANTIC-ONLY] Query: dieu kien de duoc cap giay phep kinh doanh
# ======================================================================
#
#   [1] 58 /2006/NQ-HĐND | NGHỊ QUYẾT
#       📌 Điều 1:
#       🎯 dense_dist=0.1156
#       📝 [Điều 1:] Nhà nước (chủ yếu các doanh nghiệp Trung ương) để huy động vốn cho đầu tư mở rộng sản xuất, kinh doanh. Những dự án có hiệu quả đầu tư cao, cần nhiều vốn có thể phát hành trái phiếu công trì...
#
#   [2] 35/NQ-CP | NGHỊ QUYẾT
#       📌 5. Bảo vệ quyền và lợi ích hợp pháp của doanh nghiệp
#       🎯 dense_dist=0.1170
#       📝 [5. Bảo vệ quyền và lợi ích hợp pháp của doanh nghiệp] quan có thẩm quyền giải quyết. d) Xử lý nghiêm các trường hợp cán bộ, công chức gây khó khăn, nhũng nhiễu doanh nghiệp theo quy định của pháp luậ...
#
#   [3] 35/NQ-CP | NGHỊ QUYẾT
#       📌 3. Bảo đảm quyền kinh doanh, quyền bình đẳng tiếp cận nguồn lực và cơ hội kinh doanh của doanh nghiệp
#       🎯 dense_dist=0.1184
#       📝 [3. Bảo đảm quyền kinh doanh, quyền bình đẳng tiếp cận nguồn lực và cơ hội kinh doanh của doanh nghiệp] thuộc Chính phủ, Ủy ban nhân dân các tỉnh, thành phố trực thuộc Trung ương và các cơ quan liên q...
#
#   [4] 03/NQ-CP | NGHỊ QUYẾT
#       📌 I. PHỤC HỒI KINH TẾ, CHUYỂN DỊCH CƠ CẤU VÀ NÂNG CAO CHẤT LƯỢNG TĂNG TRƯỞNG
#       🎯 dense_dist=0.1189
#       📝 [I. PHỤC HỒI KINH TẾ, CHUYỂN DỊCH CƠ CẤU VÀ NÂNG CAO CHẤT LƯỢNG TĂNG TRƯỞNG] may, da, giày; - Tiếp tục đẩy mạnh việc sắp xếp, đổi mới, phát triển và nâng cao hiệu quả hoạt động của doanh nghiệp nhà nư...
#
#   [5] 54/NQ-CP | NGHỊ QUYẾT
#       📌 3. Phát triển lực lượng doanh nghiệp; thúc đẩy kết nối giữa doanh nghiệp thuộc các thành phần kinh tế; đổi mới, phát triển kinh tế tập thể, hợp tác xã
#       🎯 dense_dist=0.1210
#       📝 [3. Phát triển lực lượng doanh nghiệp; thúc đẩy kết nối giữa doanh nghiệp thuộc các thành phần kinh tế; đổi mới, phát triển kinh tế tập thể, hợp tác xã] đai, xây dựng, môi trường, đăng ký kinh doanh, ...
#
#   ⏱  Latency: 0ms
#
# ----------------------------------------------------------------------
#
# ======================================================================
# [HYBRID] Query: trach nhiem cua Bo truong trong ban hanh van ban
# ======================================================================
#
#   [1] 36/2012/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 25. Trách nhiệm của Bộ trưởng đối với Bộ trưởng khác
#       🎯 rerank=0.9608 | rrf=0.01538 | bm25=34.83 | dense_dist=1.0000
#       📝 Điều 25. Trách nhiệm của Bộ trưởng đối với Bộ trưởng khác 1. Không ban hành văn bản trái với quy định của các Bộ trưởng khác. 2. Chủ trì, phối hợp với các Bộ trưởng khác để giải quyết những vấn đề có ...
#
#   [2] 52/2015/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 13. Trách nhiệm cập nhật văn bản
#       🎯 rerank=0.8500 | rrf=0.01562 | bm25=34.87 | dense_dist=1.0000
#       📝 [Điều 13. Trách nhiệm cập nhật văn bản] 1. Trách nhiệm cập nhật văn bản quy phạm pháp luật: a) Bộ trưởng, Thủ trưởng cơ quan ngang Bộ và Thủ trưởng cơ quan nhà nước khác ở Trung ương có trách nhiệm tổ...
#
#   [3] 86/2002/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 24. Trách nhiệm của Bộ trưởng đối với Bộ trưởng khác
#       🎯 rerank=0.7606 | rrf=0.01515 | bm25=34.81 | dense_dist=1.0000
#       📝 Điều 24. Trách nhiệm của Bộ trưởng đối với Bộ trưởng khác 1. Thực hiện những quy định quản lý nhà nước thuộc thẩm quyền của các bộ khác; không ban hành những văn bản trái với quy định của các Bộ trưởn...
#
#   [4] 178/2007/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 25. Trách nhiệm của Bộ trưởng đối với Bộ trưởng khác
#       🎯 rerank=0.7318 | rrf=0.01639 | bm25=36.00 | dense_dist=1.0000
#       📝 Điều 25. Trách nhiệm của Bộ trưởng đối với Bộ trưởng khác 1. Thực hiện các quy định quản lý nhà nước thuộc thẩm quyền của các Bộ khác; không ban hành những văn bản trái với quy định của các Bộ trưởng ...
#
#   [5] 135/2003/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 16. Thẩm quyền của Bộ trưởng, Thủ trưởng cơ quan ngang Bộ trong việc xử lý văn bản trái pháp luật
#       🎯 rerank=0.6927 | rrf=0.01587 | bm25=35.00 | dense_dist=1.0000
#       📝 [Điều 16. Thẩm quyền của Bộ trưởng, Thủ trưởng cơ quan ngang Bộ trong việc xử lý văn bản trái pháp luật] 1. Thẩm quyền của Bộ trưởng, Thủ trưởng cơ quan ngang Bộ trong việc xử lý văn bản trái pháp luậ...
#
#   ⏱  Latency: 3808.3ms
#
# ======================================================================
# [SEMANTIC-ONLY] Query: trach nhiem cua Bo truong trong ban hanh van ban
# ======================================================================
#
#   [1] 90/NQ-CP | NGHỊ QUYẾT
#       📌 Điều 3. Các Bộ trưởng, Thủ trưởng cơ quan ngang bộ, Thủ trưởng cơ quan thuộc Chính phủ, Chủ tịch Ủy ban nhân dân các tỉnh, thành phố trực thuộc trung ương và các cơ quan, tổ chức, cá nhân có liên quan chịu trách nhiệm thi hành Nghị quyết này.
#       🎯 dense_dist=0.1193
#       📝 [Điều 3. Các Bộ trưởng, Thủ trưởng cơ quan ngang bộ, Thủ trưởng cơ quan thuộc Chính phủ, Chủ tịch Ủy ban nhân dân các tỉnh, thành phố trực thuộc trung ương và các cơ quan, tổ chức, cá nhân có liên qua...
#
#   [2] 37/2011/NQ-HĐND | NGHỊ QUYẾT
#       📌 A. NHIỆM VỤ
#       🎯 dense_dist=0.1194
#       📝 [A. NHIỆM VỤ] bào dân tộc thiểu số. Phát huy dân chủ, bảo đảm quyền tự do tín ngưỡng, tôn giáo. Không ngừng nâng cao chất lượng, hiệu quả trong quản lý nhà nước về tôn giáo. 16. Công tác tổ chức bộ má...
#
#   [3] 95/2014/NQ-HĐND | NGHỊ QUYẾT
#       📌 Điều 1.
#       🎯 dense_dist=0.1215
#       📝 [Điều 1.] Nội; Đồng Hới - Hồ Chí Minh. Nghiên cứu phát triển một số tuyến bay giá rẻ và bay dịch vụ khác. Phát triển các dịch vụ bưu chính, viễn thông, tài chính, ngân hàng, tư vấn pháp luật, khoa học...
#
#   [4] 120/NQ-CP | NGHỊ QUYẾT
#       📌 5. Một số nhiệm vụ cụ thể
#       🎯 dense_dist=0.1219
#       📝 [5. Một số nhiệm vụ cụ thể] biến đổi khí hậu, trong đó có quan hệ đối tác chiến lược về biến đổi khí hậu với Hà Lan; nghiên cứu, đề xuất việc xây dựng các khuôn khổ hợp tác mới với các nước và các đối...
#
#   [5] 76/2013/NQ-HĐND | NGHỊ QUYẾT
#       📌 III. NHIỆM VỤ VÀ GIẢI PHÁP CHỦ YẾU
#       🎯 dense_dist=0.1229
#       📝 [III. NHIỆM VỤ VÀ GIẢI PHÁP CHỦ YẾU] A. NHIỆM VỤ 1. Công tác quy hoạch và quản lý đô thị Thực hiện tốt công tác quy hoạch và quản lý quy hoạch, quản lý đô thị. Tập trung rà soát, điều chỉnh, bổ sung q...
#
#   ⏱  Latency: 0ms
#
# ----------------------------------------------------------------------
#
# ======================================================================
# [HYBRID] Query: Quy định về hòa giải ở cơ sở
# ======================================================================
#
#   [1] 160/1999/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 2. Hoà giải ở cơ sở
#       🎯 rerank=0.9974 | rrf=0.01538 | bm25=0.00 | dense_dist=0.0656
#       📝 Điều 2. Hoà giải ở cơ sở 1. Hoà giải ở cơ sở là việc hướng dẫn, giúp đỡ, thuyết phục các bên tranh chấp đạt được thoả thuận, tự nguyện giải quyết với nhau những việc vi phạm pháp luật và tranh chấp nh...
#
#   [2] 35/2013/QH13 | LUẬT
#       📌 Điều 28. Trách nhiệm quản lý nhà nước về hòa giải ở cơ sở
#       🎯 rerank=0.9965 | rrf=0.01429 | bm25=0.00 | dense_dist=0.0704
#       📝 Điều 28. Trách nhiệm quản lý nhà nước về hòa giải ở cơ sở 1. Chính phủ thống nhất quản lý nhà nước về hòa giải ở cơ sở. 2. Bộ Tư pháp chịu trách nhiệm trước Chính phủ thực hiện quản lý nhà nước về hòa...
#
#   [3] 35/2013/QH13 | LUẬT
#       📌 Điều 4. Nguyên tắc tổ chức, hoạt động hòa giải ở cơ sở
#       🎯 rerank=0.9955 | rrf=0.01639 | bm25=0.00 | dense_dist=0.0591
#       📝 Điều 4. Nguyên tắc tổ chức, hoạt động hòa giải ở cơ sở 1. Tôn trọng sự tự nguyện của các bên; không bắt buộc, áp đặt các bên trong hòa giải ở cơ sở. 2. Bảo đảm phù hợp với chính sách, pháp luật của Nh...
#
#   [4] 15/2014/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 5. Phạm vi hòa giải ở cơ sở
#       🎯 rerank=0.9954 | rrf=0.01515 | bm25=0.00 | dense_dist=0.0690
#       📝 [Điều 5. Phạm vi hòa giải ở cơ sở] 1. Hòa giải ở cơ sở được tiến hành đối với các mâu thuẫn, tranh chấp, vi phạm pháp luật sau đây: a) Mâu thuẫn giữa các bên (do khác nhau về quan niệm sống, lối sống,...
#
#   [5] 15/2014/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 1. Phạm vi điều chỉnh
#       🎯 rerank=0.9952 | rrf=0.01493 | bm25=0.00 | dense_dist=0.0693
#       📝 Điều 1. Phạm vi điều chỉnh Nghị định này quy định chi tiết về phạm vi hòa giải ở cơ sở; hỗ trợ kinh phí cho công tác hòa giải ở cơ sở, hòa giải viên và một số biện pháp thi hành Luật hòa giải ở cơ sở....
#
#   ⏱  Latency: 3498.2ms
#
# ======================================================================
# [SEMANTIC-ONLY] Query: Quy định về hòa giải ở cơ sở
# ======================================================================
#
#   [1] 35/2013/QH13 | LUẬT
#       📌 Điều 4. Nguyên tắc tổ chức, hoạt động hòa giải ở cơ sở
#       🎯 dense_dist=0.0591
#       📝 Điều 4. Nguyên tắc tổ chức, hoạt động hòa giải ở cơ sở 1. Tôn trọng sự tự nguyện của các bên; không bắt buộc, áp đặt các bên trong hòa giải ở cơ sở. 2. Bảo đảm phù hợp với chính sách, pháp luật của Nh...
#
#   [2] 35/2013/QH13 | LUẬT
#       📌 Điều 3. Phạm vi hòa giải ở cơ sở
#       🎯 dense_dist=0.0600
#       📝 Điều 3. Phạm vi hòa giải ở cơ sở 1. Việc hòa giải ở cơ sở được tiến hành đối với các mâu thuẫn, tranh chấp, vi phạm pháp luật, trừ các trường hợp sau đây: a) Mâu thuẫn, tranh chấp xâm phạm lợi ích của...
#
#   [3] 35/2013/QH13 | LUẬT
#       📌 Điều 5. Chính sách của Nhà nước về hòa giải ở cơ sở
#       🎯 dense_dist=0.0613
#       📝 Điều 5. Chính sách của Nhà nước về hòa giải ở cơ sở 1. Khuyến khích các bên giải quyết mâu thuẫn, tranh chấp bằng hình thức hòa giải ở cơ sở và các hình thức hòa giải thích hợp khác. Khuyến khích nhữn...
#
#   [4] 35/2013/QH13 | LUẬT
#       📌 Điều 1. Phạm vi điều chỉnh
#       🎯 dense_dist=0.0615
#       📝 Điều 1. Phạm vi điều chỉnh 1. Luật này quy định nguyên tắc, chính sách của Nhà nước về hòa giải ở cơ sở, hòa giải viên, tổ hòa giải; hoạt động hòa giải ở cơ sở; trách nhiệm của cơ quan, tổ chức trong ...
#
#   [5] 160/1999/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 2. Hoà giải ở cơ sở
#       🎯 dense_dist=0.0656
#       📝 Điều 2. Hoà giải ở cơ sở 1. Hoà giải ở cơ sở là việc hướng dẫn, giúp đỡ, thuyết phục các bên tranh chấp đạt được thoả thuận, tự nguyện giải quyết với nhau những việc vi phạm pháp luật và tranh chấp nh...
#
#   ⏱  Latency: 0ms
#
# ----------------------------------------------------------------------
#
# ======================================================================
# [HYBRID] Query: Điều kiện thành lập doanh nghiệp
# ======================================================================
#
#   [1] 23/2022/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 4. Điều kiện thành lập
#       🎯 rerank=0.9980 | rrf=0.01613 | bm25=0.00 | dense_dist=0.0794
#       📝 Điều 4. Điều kiện thành lập Doanh nghiệp do Nhà nước nắm giữ 100% vốn điều lệ chỉ được xem xét thành lập khi đáp ứng đủ các điều kiện sau: 1. Có ngành, lĩnh vực hoạt động thuộc phạm vi đầu tư vốn nhà ...
#
#   [2] 23/2022/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 4. Điều kiện thành lập
#       🎯 rerank=0.9980 | rrf=0.01562 | bm25=14.29 | dense_dist=1.0000
#       📝 Điều 4. Điều kiện thành lập Doanh nghiệp do Nhà nước nắm giữ 100% vốn điều lệ chỉ được xem xét thành lập khi đáp ứng đủ các điều kiện sau: 1. Có ngành, lĩnh vực hoạt động thuộc phạm vi đầu tư vốn nhà ...
#
#   [3] 48-LCT/HĐNN8 | LUẬT
#       📌 Điều 9.
#       🎯 rerank=0.9948 | rrf=0.01639 | bm25=0.00 | dense_dist=0.0767
#       📝 Điều 9. Cá nhân có quyền thành lập doanh nghiệp tư nhân, phải có đủ các điều kiện sau đây mới được cấp giấy phép thành lập: 1- Mục tiêu, ngành, nghề kinh doanh rõ ràng; có trụ sở giao dịch và phương á...
#
#   [4] 47-LCT/HĐNN8 | LUẬT
#       📌 Công dân, tổ chức có quyền tham gia thành lập công ty phải có các điều kiện sau đây mới được cấp giấy phép thành lập:.
#       🎯 rerank=0.9933 | rrf=0.01587 | bm25=0.00 | dense_dist=0.0839
#       📝 Công dân, tổ chức có quyền tham gia thành lập công ty phải có các điều kiện sau đây mới được cấp giấy phép thành lập:. 1- Mục tiêu, ngành, nghề kinh doanh rõ ràng, có phương án kinh doanh ban đầu; có ...
#
#   [5] 23/2022/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 11. Quyết định thành lập doanh nghiệp
#       🎯 rerank=0.9894 | rrf=0.01449 | bm25=0.00 | dense_dist=0.0917
#       📝 Điều 11. Quyết định thành lập doanh nghiệp Quyết định thành lập doanh nghiệp bao gồm các nội dung chủ yếu sau: 1. Tên doanh nghiệp, bao gồm tên đầy đủ bằng tiếng Việt, tên bằng tiếng nước ngoài, tên v...
#
#   ⏱  Latency: 3463.4ms
#
# ======================================================================
# [SEMANTIC-ONLY] Query: Điều kiện thành lập doanh nghiệp
# ======================================================================
#
#   [1] 48-LCT/HĐNN8 | LUẬT
#       📌 Điều 9.
#       🎯 dense_dist=0.0767
#       📝 Điều 9. Cá nhân có quyền thành lập doanh nghiệp tư nhân, phải có đủ các điều kiện sau đây mới được cấp giấy phép thành lập: 1- Mục tiêu, ngành, nghề kinh doanh rõ ràng; có trụ sở giao dịch và phương á...
#
#   [2] 23/2022/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 4. Điều kiện thành lập
#       🎯 dense_dist=0.0794
#       📝 Điều 4. Điều kiện thành lập Doanh nghiệp do Nhà nước nắm giữ 100% vốn điều lệ chỉ được xem xét thành lập khi đáp ứng đủ các điều kiện sau: 1. Có ngành, lĩnh vực hoạt động thuộc phạm vi đầu tư vốn nhà ...
#
#   [3] 47-LCT/HĐNN8 | LUẬT
#       📌 Công dân, tổ chức có quyền tham gia thành lập công ty phải có các điều kiện sau đây mới được cấp giấy phép thành lập:.
#       🎯 dense_dist=0.0839
#       📝 Công dân, tổ chức có quyền tham gia thành lập công ty phải có các điều kiện sau đây mới được cấp giấy phép thành lập:. 1- Mục tiêu, ngành, nghề kinh doanh rõ ràng, có phương án kinh doanh ban đầu; có ...
#
#   [4] 48-LCT/HĐNN8 | LUẬT
#       📌 Điều 8.
#       🎯 dense_dist=0.0872
#       📝 Điều 8. Cá nhân muốn thành lập doanh nghiệp tư nhân, phải gửi đơn xin phép thành lập doanh nghiệp đến Uỷ ban nhân dân có thẩm quyền cấp giấy phép theo quy định của Hội đồng bộ trưởng. Đơn xin thành lậ...
#
#   [5] 48-LCT/HĐNN8 | LUẬT
#       📌 Điều 1.
#       🎯 dense_dist=0.0874
#       📝 Điều 1. Công dân Việt Nam đủ 18 tuổi có quyền thành lập doanh nghiệp tư nhân theo quy định của Luật này....
#
#   ⏱  Latency: 0ms
#
# ----------------------------------------------------------------------
#
# ======================================================================
# [HYBRID] Query: Quyền và nghĩa vụ của người lao động
# ======================================================================
#
#   [1] 45/2019/QH14 | LUẬT
#       📌 Điều 5. Quyền và nghĩa vụ của người lao động
#       🎯 rerank=0.9995 | rrf=0.01613 | bm25=0.00 | dense_dist=0.0624
#       📝 Điều 5. Quyền và nghĩa vụ của người lao động 1. Người lao động có các quyền sau đây: a) Làm việc; tự do lựa chọn việc làm, nơi làm việc, nghề nghiệp, học nghề, nâng cao trình độ nghề nghiệp; không bị ...
#
#   [2] 10/2012/QH13 | LUẬT
#       📌 Điều 5. Quyền và nghĩa vụ của người lao động
#       🎯 rerank=0.9995 | rrf=0.01639 | bm25=0.00 | dense_dist=0.0617
#       📝 Điều 5. Quyền và nghĩa vụ của người lao động 1. Người lao động có các quyền sau đây: a) Làm việc, tự do lựa chọn việc làm, nghề nghiệp, học nghề, nâng cao trình độ nghề nghiệp và không bị phân biệt đố...
#
#   [3] 10/2012/QH13 | LUẬT
#       📌 Điều 6. Quyền và nghĩa vụ của người sử dụng lao động
#       🎯 rerank=0.9983 | rrf=0.01515 | bm25=0.00 | dense_dist=0.0796
#       📝 Điều 6. Quyền và nghĩa vụ của người sử dụng lao động 1. Người sử dụng lao động có các quyền sau đây: a) Tuyển dụng, bố trí, điều hành lao động theo nhu cầu sản xuất, kinh doanh; khen thưởng và xử lý v...
#
#   [4] 45/2019/QH14 | LUẬT
#       📌 Điều 6. Quyền và nghĩa vụ của người sử dụng lao động
#       🎯 rerank=0.9981 | rrf=0.01562 | bm25=0.00 | dense_dist=0.0752
#       📝 Điều 6. Quyền và nghĩa vụ của người sử dụng lao động 1. Người sử dụng lao động có các quyền sau đây: a) Tuyển dụng, bố trí, quản lý, điều hành, giám sát lao động; khen thưởng và xử lý vi phạm kỷ luật ...
#
#   [5] 89/2007/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 3. Quyền, nghĩa vụ của ngư­ời quản lý công ty và ng­ười lao động
#       🎯 rerank=0.9953 | rrf=0.01613 | bm25=27.64 | dense_dist=1.0000
#       📝 Điều 3. Quyền, nghĩa vụ của ngư­ời quản lý công ty và ng­ười lao động 1. Ng­ười quản lý và ngư­ời lao động trong công ty có nghĩa vụ thực hiện đúng hợp đồng lao động, thoả ư­ớc lao động tập thể, chấp ...
#
#   ⏱  Latency: 3186.5ms
#
# ======================================================================
# [SEMANTIC-ONLY] Query: Quyền và nghĩa vụ của người lao động
# ======================================================================
#
#   [1] 10/2012/QH13 | LUẬT
#       📌 Điều 5. Quyền và nghĩa vụ của người lao động
#       🎯 dense_dist=0.0617
#       📝 Điều 5. Quyền và nghĩa vụ của người lao động 1. Người lao động có các quyền sau đây: a) Làm việc, tự do lựa chọn việc làm, nghề nghiệp, học nghề, nâng cao trình độ nghề nghiệp và không bị phân biệt đố...
#
#   [2] 45/2019/QH14 | LUẬT
#       📌 Điều 5. Quyền và nghĩa vụ của người lao động
#       🎯 dense_dist=0.0624
#       📝 Điều 5. Quyền và nghĩa vụ của người lao động 1. Người lao động có các quyền sau đây: a) Làm việc; tự do lựa chọn việc làm, nơi làm việc, nghề nghiệp, học nghề, nâng cao trình độ nghề nghiệp; không bị ...
#
#   [3] 35-L/CTN | LUẬT
#       📌 Điều 7.
#       🎯 dense_dist=0.0742
#       📝 Điều 7. 1- Người lao động được trả lương trên cơ sở thoả thuận với người sử dụng lao động nhưng không thấp hơn mức lương tối thiểu do Nhà nước quy định và theo năng suất, chất lượng, hiệu quả công việ...
#
#   [4] 45/2019/QH14 | LUẬT
#       📌 Điều 6. Quyền và nghĩa vụ của người sử dụng lao động
#       🎯 dense_dist=0.0752
#       📝 Điều 6. Quyền và nghĩa vụ của người sử dụng lao động 1. Người sử dụng lao động có các quyền sau đây: a) Tuyển dụng, bố trí, quản lý, điều hành, giám sát lao động; khen thưởng và xử lý vi phạm kỷ luật ...
#
#   [5] 35-L/CTN | LUẬT
#       📌 Điều 8.
#       🎯 dense_dist=0.0793
#       📝 Điều 8. 1- Người sử dụng lao động có quyền tuyển chọn lao động, bố trí, Điều hành lao động theo nhu cầu sản xuất, kinh doanh; có quyền khen thưởng và xử lý các vi phạm kỷ luật lao động theo quy định c...
#
#   ⏱  Latency: 0ms
#
# ----------------------------------------------------------------------
#
# ======================================================================
# [HYBRID] Query: thủ tục xin cấp phép xây dựng nhà ở
# ======================================================================
#
#   [1] 12/2009/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 21. Hồ sơ xin cấp Giấy phép xây dựng nhà ở nông thôn
#       🎯 rerank=0.9906 | rrf=0.01493 | bm25=0.00 | dense_dist=0.0867
#       📝 Điều 21. Hồ sơ xin cấp Giấy phép xây dựng nhà ở nông thôn Hồ sơ xin cấp Giấy phép xây dựng nhà ở nông thôn gồm: 1. Đơn xin cấp Giấy phép xây dựng theo mẫu tại Phụ lục V kèm theo Nghị định này. 2. Bản ...
#
#   [2] 25/NQ-CP | NGHỊ QUYẾT
#       📌 3. Thủ tục “Cấp giấy phép xây dựng nhà ở riêng lẻ tại những điểm dân cư nông thôn đã có quy hoạch xây dựng được duyệt thuộc địa giới hành chính do mình quản lý” - B-BXD-046345-TT
#       🎯 rerank=0.9899 | rrf=0.01429 | bm25=0.00 | dense_dist=0.0870
#       📝 3. Thủ tục “Cấp giấy phép xây dựng nhà ở riêng lẻ tại những điểm dân cư nông thôn đã có quy hoạch xây dựng được duyệt thuộc địa giới hành chính do mình quản lý” - B-BXD-046345-TT - Quy định cụ thể về ...
#
#   [3] 64/2012/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 9. Quy trình xin cấp giấy phép xây dựng
#       🎯 rerank=0.9819 | rrf=0.01587 | bm25=0.00 | dense_dist=0.0826
#       📝 [Điều 9. Quy trình xin cấp giấy phép xây dựng] văn bản lấy ý kiến của các cơ quan quản lý nhà nước về những lĩnh vực liên quan đến công trình xây dựng. 5. Trong thời gian 10 ngày làm việc đối với công...
#
#   [4] 64/2012/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 9. Quy trình xin cấp giấy phép xây dựng
#       🎯 rerank=0.9816 | rrf=0.01562 | bm25=0.00 | dense_dist=0.0850
#       📝 [Điều 9. Quy trình xin cấp giấy phép xây dựng] 1. Cơ quan cấp giấy phép xây dựng có trách nhiệm tiếp nhận hồ sơ của tổ chức, cá nhân đề nghị cấp giấy phép xây dựng; kiểm tra hồ sơ; ghi giấy biên nhận ...
#
#   [5] 12/2009/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 20. Hồ sơ xin cấp Giấy phép xây dựng công trình và nhà ở đô thị
#       🎯 rerank=0.9766 | rrf=0.01613 | bm25=0.00 | dense_dist=0.0817
#       📝 Điều 20. Hồ sơ xin cấp Giấy phép xây dựng công trình và nhà ở đô thị Hồ sơ xin cấp Giấy phép xây dựng gồm: 1. Đơn xin cấp Giấy phép xây dựng theo mẫu tại Phụ lục IV kèm theo Nghị định này. Trường hợp ...
#
#   ⏱  Latency: 3759.9ms
#
# ======================================================================
# [SEMANTIC-ONLY] Query: thủ tục xin cấp phép xây dựng nhà ở
# ======================================================================
#
#   [1] 16/2005/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 18. Hồ sơ xin cấp giấy phép xây dựng công trình và nhà ở đô thị
#       🎯 dense_dist=0.0800
#       📝 Điều 18. Hồ sơ xin cấp giấy phép xây dựng công trình và nhà ở đô thị Hồ sơ xin cấp giấy phép xây dựng gồm: 1. Đơn xin cấp giấy phép xây dựng theo mẫu tại Phụ lục 4 kèm theo Nghị định này. Trường hợp x...
#
#   [2] 12/2009/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 20. Hồ sơ xin cấp Giấy phép xây dựng công trình và nhà ở đô thị
#       🎯 dense_dist=0.0817
#       📝 Điều 20. Hồ sơ xin cấp Giấy phép xây dựng công trình và nhà ở đô thị Hồ sơ xin cấp Giấy phép xây dựng gồm: 1. Đơn xin cấp Giấy phép xây dựng theo mẫu tại Phụ lục IV kèm theo Nghị định này. Trường hợp ...
#
#   [3] 64/2012/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 9. Quy trình xin cấp giấy phép xây dựng
#       🎯 dense_dist=0.0826
#       📝 [Điều 9. Quy trình xin cấp giấy phép xây dựng] văn bản lấy ý kiến của các cơ quan quản lý nhà nước về những lĩnh vực liên quan đến công trình xây dựng. 5. Trong thời gian 10 ngày làm việc đối với công...
#
#   [4] 64/2012/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 9. Quy trình xin cấp giấy phép xây dựng
#       🎯 dense_dist=0.0850
#       📝 [Điều 9. Quy trình xin cấp giấy phép xây dựng] 1. Cơ quan cấp giấy phép xây dựng có trách nhiệm tiếp nhận hồ sơ của tổ chức, cá nhân đề nghị cấp giấy phép xây dựng; kiểm tra hồ sơ; ghi giấy biên nhận ...
#
#   [5] 50/2014/QH13 | LUẬT
#       📌 Điều 95. Hồ sơ đề nghị cấp giấy phép xây dựng mới
#       🎯 dense_dist=0.0852
#       📝 [Điều 95. Hồ sơ đề nghị cấp giấy phép xây dựng mới] 1. Hồ sơ đề nghị cấp giấy phép xây dựng mới đối với nhà ở riêng lẻ gồm: a) Đơn đề nghị cấp giấy phép xây dựng; b) Bản sao một trong những giấy tờ ch...
#
#   ⏱  Latency: 0ms
#
# ----------------------------------------------------------------------
#
# ======================================================================
# [HYBRID] Query: xử phạt vi phạm hành chính trong lĩnh vực giao thông
# ======================================================================
#
#   [1] 152/2005/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 5. Hình thức xử phạt vi phạm hành chính
#       🎯 rerank=0.9992 | rrf=0.01515 | bm25=0.00 | dense_dist=0.0675
#       📝 Điều 5. Hình thức xử phạt vi phạm hành chính 1. Đối với mỗi hành vi vi phạm hành chính trong lĩnh vực giao thông đường bộ được quy định tại Nghị định này, cá nhân, tổ chức vi phạm phải chịu một trong ...
#
#   [2] 152/2005/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 4. Nguyên tắc xử phạt vi phạm hành chính và áp dụng biện pháp khác
#       🎯 rerank=0.9988 | rrf=0.01639 | bm25=0.00 | dense_dist=0.0645
#       📝 [Điều 4. Nguyên tắc xử phạt vi phạm hành chính và áp dụng biện pháp khác] 1. Mọi vi phạm hành chính trong lĩnh vực giao thông đường bộ phải được phát hiện kịp thời và phải bị đình chỉ ngay. Việc xử ph...
#
#   [3] 146/2007/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 5. Hình thức xử phạt vi phạm hành chính
#       🎯 rerank=0.9988 | rrf=0.01471 | bm25=0.00 | dense_dist=0.0683
#       📝 Điều 5. Hình thức xử phạt vi phạm hành chính 1. Đối với mỗi hành vi vi phạm hành chính trong lĩnh vực giao thông đường bộ được quy định tại Nghị định này, cá nhân, tổ chức vi phạm phải chịu một trong ...
#
#   [4] 34/2010/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 5. Hình thức xử phạt vi phạm hành chính và các biện pháp khắc phục hậu quả
#       🎯 rerank=0.9988 | rrf=0.01429 | bm25=0.00 | dense_dist=0.0690
#       📝 Điều 5. Hình thức xử phạt vi phạm hành chính và các biện pháp khắc phục hậu quả 1. Đối với mỗi hành vi vi phạm hành chính trong lĩnh vực giao thông đường bộ được quy định tại Nghị định này, cá nhân, t...
#
#   [5] 146/2007/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 4. Nguyên tắc xử phạt vi phạm hành chính
#       🎯 rerank=0.9988 | rrf=0.01587 | bm25=0.00 | dense_dist=0.0669
#       📝 Điều 4. Nguyên tắc xử phạt vi phạm hành chính 1. Mọi vi phạm hành chính trong lĩnh vực giao thông đường bộ phải được phát hiện kịp thời và phải bị đình chỉ ngay. Việc xử phạt phải thực hiện theo đúng ...
#
#   ⏱  Latency: 4155.1ms
#
# ======================================================================
# [SEMANTIC-ONLY] Query: xử phạt vi phạm hành chính trong lĩnh vực giao thông
# ======================================================================
#
#   [1] 152/2005/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 4. Nguyên tắc xử phạt vi phạm hành chính và áp dụng biện pháp khác
#       🎯 dense_dist=0.0645
#       📝 [Điều 4. Nguyên tắc xử phạt vi phạm hành chính và áp dụng biện pháp khác] 1. Mọi vi phạm hành chính trong lĩnh vực giao thông đường bộ phải được phát hiện kịp thời và phải bị đình chỉ ngay. Việc xử ph...
#
#   [2] 46/2016/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 2. Đối tượng áp dụng
#       🎯 dense_dist=0.0659
#       📝 Điều 2. Đối tượng áp dụng 1. Cá nhân, tổ chức có hành vi vi phạm hành chính trong lĩnh vực giao thông đường bộ, đường sắt trên lãnh thổ nước Cộng hòa xã hội chủ nghĩa Việt Nam. 2. Người có thẩm quyền ...
#
#   [3] 146/2007/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 4. Nguyên tắc xử phạt vi phạm hành chính
#       🎯 dense_dist=0.0669
#       📝 Điều 4. Nguyên tắc xử phạt vi phạm hành chính 1. Mọi vi phạm hành chính trong lĩnh vực giao thông đường bộ phải được phát hiện kịp thời và phải bị đình chỉ ngay. Việc xử phạt phải thực hiện theo đúng ...
#
#   [4] 34/2010/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 4. Nguyên tắc xử phạt vi phạm hành chính
#       🎯 dense_dist=0.0673
#       📝 Điều 4. Nguyên tắc xử phạt vi phạm hành chính 1. Nguyên tắc xử phạt vi phạm hành chính trong lĩnh vực giao thông đường bộ được thực hiện theo quy định tại Điều 3 của Pháp lệnh Xử lý vi phạm hành chính...
#
#   [5] 34/2010/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 1. Phạm vi điều chỉnh
#       🎯 dense_dist=0.0673
#       📝 Điều 1. Phạm vi điều chỉnh 1. Nghị định này quy định về hành vi vi phạm, hình thức và mức xử phạt, thẩm quyền và thủ tục xử phạt vi phạm hành chính trong lĩnh vực giao thông đường bộ. 2. Vi phạm hành ...
#
#   ⏱  Latency: 0ms
#
# ----------------------------------------------------------------------
#
# ======================================================================
# [HYBRID] Query: quy trình bổ nhiệm cán bộ công chức
# ======================================================================
#
#   [1] 138/2020/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 46. Trình tự, thủ tục bổ nhiệm công chức giữ chức vụ lãnh đạo, quản lý thuộc thẩm quyền quản lý của Bộ, ngành, địa phương
#       🎯 rerank=0.9966 | rrf=0.01613 | bm25=0.00 | dense_dist=0.0695
#       📝 [Điều 46. Trình tự, thủ tục bổ nhiệm công chức giữ chức vụ lãnh đạo, quản lý thuộc thẩm quyền quản lý của Bộ, ngành, địa phương] 1. Xin chủ trương bổ nhiệm: a) Cơ quan, tổ chức có nhu cầu bổ nhiệm côn...
#
#   [2] 138/2020/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 46. Trình tự, thủ tục bổ nhiệm công chức giữ chức vụ lãnh đạo, quản lý thuộc thẩm quyền quản lý của Bộ, ngành, địa phương
#       🎯 rerank=0.9951 | rrf=0.01562 | bm25=0.00 | dense_dist=0.0712
#       📝 [Điều 46. Trình tự, thủ tục bổ nhiệm công chức giữ chức vụ lãnh đạo, quản lý thuộc thẩm quyền quản lý của Bộ, ngành, địa phương] kín). Nguyên tắc lựa chọn: Người đạt số phiếu cao nhất, đạt tỷ lệ trên ...
#
#   [3] 138/2020/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 46. Trình tự, thủ tục bổ nhiệm công chức giữ chức vụ lãnh đạo, quản lý thuộc thẩm quyền quản lý của Bộ, ngành, địa phương
#       🎯 rerank=0.9917 | rrf=0.01493 | bm25=0.00 | dense_dist=0.0723
#       📝 [Điều 46. Trình tự, thủ tục bổ nhiệm công chức giữ chức vụ lãnh đạo, quản lý thuộc thẩm quyền quản lý của Bộ, ngành, địa phương] ý kiến của cán bộ chủ chốt về nhân sự được tập thể lãnh đạo giới thiệu ...
#
#   [4] 564/NQ-UBTVQH13 | NGHỊ QUYẾT
#       📌 2. Kết quả thực hiện chính sách, pháp luật về tuyển dụng, đào tạo, bổ nhiệm đối với đội ngũ cán bộ, công chức, viên chức
#       🎯 rerank=0.9863 | rrf=0.01515 | bm25=31.26 | dense_dist=1.0000
#       📝 [2. Kết quả thực hiện chính sách, pháp luật về tuyển dụng, đào tạo, bổ nhiệm đối với đội ngũ cán bộ, công chức, viên chức] 2.1. Tuyển dụng công chức, viên chức - Căn cứ tuyển dụng: yêu cầu nhiệm vụ, v...
#
#   [5] 115/2020/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 46. Trình tự, thủ tục bổ nhiệm viên chức quản lý
#       🎯 rerank=0.9822 | rrf=0.01587 | bm25=0.00 | dense_dist=0.0704
#       📝 [Điều 46. Trình tự, thủ tục bổ nhiệm viên chức quản lý] 1. Xin chủ trương bổ nhiệm a) Đơn vị sự nghiệp công lập có nhu cầu bổ nhiệm viên chức quản lý phải trình cơ quan, đơn vị có thẩm quyền bổ nhiệm ...
#
#   ⏱  Latency: 3852.0ms
#
# ======================================================================
# [SEMANTIC-ONLY] Query: quy trình bổ nhiệm cán bộ công chức
# ======================================================================
#
#   [1] 138/2020/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 46. Trình tự, thủ tục bổ nhiệm công chức giữ chức vụ lãnh đạo, quản lý thuộc thẩm quyền quản lý của Bộ, ngành, địa phương
#       🎯 dense_dist=0.0647
#       📝 [Điều 46. Trình tự, thủ tục bổ nhiệm công chức giữ chức vụ lãnh đạo, quản lý thuộc thẩm quyền quản lý của Bộ, ngành, địa phương] tổng số người được triệu tập giới thiệu thì được lựa chọn. Trường hợp k...
#
#   [2] 138/2020/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 46. Trình tự, thủ tục bổ nhiệm công chức giữ chức vụ lãnh đạo, quản lý thuộc thẩm quyền quản lý của Bộ, ngành, địa phương
#       🎯 dense_dist=0.0695
#       📝 [Điều 46. Trình tự, thủ tục bổ nhiệm công chức giữ chức vụ lãnh đạo, quản lý thuộc thẩm quyền quản lý của Bộ, ngành, địa phương] 1. Xin chủ trương bổ nhiệm: a) Cơ quan, tổ chức có nhu cầu bổ nhiệm côn...
#
#   [3] 115/2020/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 46. Trình tự, thủ tục bổ nhiệm viên chức quản lý
#       🎯 dense_dist=0.0704
#       📝 [Điều 46. Trình tự, thủ tục bổ nhiệm viên chức quản lý] 1. Xin chủ trương bổ nhiệm a) Đơn vị sự nghiệp công lập có nhu cầu bổ nhiệm viên chức quản lý phải trình cơ quan, đơn vị có thẩm quyền bổ nhiệm ...
#
#   [4] 138/2020/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 46. Trình tự, thủ tục bổ nhiệm công chức giữ chức vụ lãnh đạo, quản lý thuộc thẩm quyền quản lý của Bộ, ngành, địa phương
#       🎯 dense_dist=0.0712
#       📝 [Điều 46. Trình tự, thủ tục bổ nhiệm công chức giữ chức vụ lãnh đạo, quản lý thuộc thẩm quyền quản lý của Bộ, ngành, địa phương] kín). Nguyên tắc lựa chọn: Người đạt số phiếu cao nhất, đạt tỷ lệ trên ...
#
#   [5] 115/2020/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 46. Trình tự, thủ tục bổ nhiệm viên chức quản lý
#       🎯 dense_dist=0.0720
#       📝 [Điều 46. Trình tự, thủ tục bổ nhiệm viên chức quản lý] ban thường vụ đảng ủy hoặc đảng ủy đơn vị (những nơi không có ban thường vụ) về nhân sự được đề nghị bổ nhiệm; tập thể lãnh đạo thảo luận, nhận ...
#
#   ⏱  Latency: 0ms
#
# ----------------------------------------------------------------------
#
# ======================================================================
# [HYBRID] Query: bảo hiểm xã hội bắt buộc cho người lao động
# ======================================================================
#
#   [1] 143/2018/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 5. Các chế độ bảo hiểm xã hội bắt buộc
#       🎯 rerank=0.9950 | rrf=0.01587 | bm25=0.00 | dense_dist=0.0750
#       📝 Điều 5. Các chế độ bảo hiểm xã hội bắt buộc 1. Người lao động quy định tại khoản 1 Điều 2 của Nghị định này thực hiện các chế độ bảo hiểm xã hội bắt buộc sau đây: ốm đau; thai sản; bảo hiểm tai nạn la...
#
#   [2] 35-L/CTN | LUẬT
#       📌 Loại hình bảo hiểm xã hội bắt buộc được áp dụng đối với những doanh nghiệp sử dụng từ 10 người lao động trở lên. Ở những doanh nghiệp này, người sử dụng lao động, người lao động phải đóng bảo hiểm xã hội theo quy định tại Điều 149 của Bộ luật này và người lao động được hưởng các chế độ trợ cấp bảo hiểm xã hội ốm đau, tai nạn lao động, bệnh nghề nghiệp, thai sản, hưu trí và tử tuất.
#       🎯 rerank=0.9942 | rrf=0.01613 | bm25=0.00 | dense_dist=0.0745
#       📝 Loại hình bảo hiểm xã hội bắt buộc được áp dụng đối với những doanh nghiệp sử dụng từ 10 người lao động trở lên. Ở những doanh nghiệp này, người sử dụng lao động, người lao động phải đóng bảo hiểm xã ...
#
#   [3] 35/2002/QH10 | LUẬT
#       📌 36. Điều 141 được sửa đổi, bổ sung như sau:
#       🎯 rerank=0.9935 | rrf=0.01471 | bm25=0.00 | dense_dist=0.0803
#       📝 36. Điều 141 được sửa đổi, bổ sung như sau: "Điều 141 1- Loại hình bảo hiểm xã hội bắt buộc được áp dụng đối với doanh nghiệp, cơ quan, tổ chức có sử dụng lao động làm việc theo hợp đồng lao động có t...
#
#   [4] 71/2006/QH11 | LUẬT
#       📌 Điều 2. Đối tượng áp dụng
#       🎯 rerank=0.9933 | rrf=0.01538 | bm25=0.00 | dense_dist=0.0769
#       📝 [Điều 2. Đối tượng áp dụng] 1. Người lao động tham gia bảo hiểm xã hội bắt buộc là công dân Việt Nam, bao gồm: a) Người làm việc theo hợp đồng lao động không xác định thời hạn, hợp đồng lao động có th...
#
#   [5] 58/2014/QH13 | LUẬT
#       📌 Điều 2. Đối tượng áp dụng
#       🎯 rerank=0.9908 | rrf=0.01493 | bm25=0.00 | dense_dist=0.0800
#       📝 [Điều 2. Đối tượng áp dụng] 1. Người lao động là công dân Việt Nam thuộc đối tượng tham gia bảo hiểm xã hội bắt buộc, bao gồm: a) Người làm việc theo hợp đồng lao động không xác định thời hạn, hợp đồn...
#
#   ⏱  Latency: 3798.3ms
#
# ======================================================================
# [SEMANTIC-ONLY] Query: bảo hiểm xã hội bắt buộc cho người lao động
# ======================================================================
#
#   [1] 61/1998/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 2. Bảo hiểm y tế bắt buộc được áp dụng đối với những trường hợp sau:
#       🎯 dense_dist=0.0725
#       📝 Điều 2. Bảo hiểm y tế bắt buộc được áp dụng đối với những trường hợp sau: 1. Người lao động Việt Nam làm việc trong: a) Các doanh nghiệp Nhà nước, kể cả các doanh nghiệp thuộc lực lượng vũ trang; b) C...
#
#   [2] 35-L/CTN | LUẬT
#       📌 Loại hình bảo hiểm xã hội bắt buộc được áp dụng đối với những doanh nghiệp sử dụng từ 10 người lao động trở lên. Ở những doanh nghiệp này, người sử dụng lao động, người lao động phải đóng bảo hiểm xã hội theo quy định tại Điều 149 của Bộ luật này và người lao động được hưởng các chế độ trợ cấp bảo hiểm xã hội ốm đau, tai nạn lao động, bệnh nghề nghiệp, thai sản, hưu trí và tử tuất.
#       🎯 dense_dist=0.0745
#       📝 Loại hình bảo hiểm xã hội bắt buộc được áp dụng đối với những doanh nghiệp sử dụng từ 10 người lao động trở lên. Ở những doanh nghiệp này, người sử dụng lao động, người lao động phải đóng bảo hiểm xã ...
#
#   [3] 143/2018/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 5. Các chế độ bảo hiểm xã hội bắt buộc
#       🎯 dense_dist=0.0750
#       📝 Điều 5. Các chế độ bảo hiểm xã hội bắt buộc 1. Người lao động quy định tại khoản 1 Điều 2 của Nghị định này thực hiện các chế độ bảo hiểm xã hội bắt buộc sau đây: ốm đau; thai sản; bảo hiểm tai nạn la...
#
#   [4] 33/2016/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 3. Các chế độ bảo hiểm xã hội bắt buộc
#       🎯 dense_dist=0.0767
#       📝 Điều 3. Các chế độ bảo hiểm xã hội bắt buộc 1. Các chế độ bảo hiểm xã hội bắt buộc quy định tại Khoản 1 Điều 4 Luật Bảo hiểm xã hội, bao gồm: Ốm đau; thai sản; tai nạn lao động, bệnh nghề nghiệp; hưu ...
#
#   [5] 71/2006/QH11 | LUẬT
#       📌 Điều 2. Đối tượng áp dụng
#       🎯 dense_dist=0.0769
#       📝 [Điều 2. Đối tượng áp dụng] 1. Người lao động tham gia bảo hiểm xã hội bắt buộc là công dân Việt Nam, bao gồm: a) Người làm việc theo hợp đồng lao động không xác định thời hạn, hợp đồng lao động có th...
#
#   ⏱  Latency: 0ms
#
# ----------------------------------------------------------------------

# %% [markdown]
# ## 10. Test Queries — Forms & Examples

# %%
# ============================================================
# TEST FORMS & EXAMPLES
# ============================================================

test_form_queries = [
    "soạn thảo công văn gửi sở tài chính",
    "viết giấy mời họp ban lãnh đạo",
    "làm tờ trình đề nghị phê duyệt dự án",
    "giấy giới thiệu cán bộ đi công tác",
    "quyết định bổ nhiệm trưởng phòng",
    "báo cáo tình hình thực hiện nhiệm vụ",
]

for query in test_form_queries:
    res_forms    = retriever_forms.retrieve(query, use_reranker=True)
    res_examples = retriever_examples.retrieve(query, use_reranker=True)
    print_forms_results(res_forms, query)
    print_examples_results(res_examples, query)
# Out:
# ======================================================================
# [HYBRID - FORMS] Query: soạn thảo công văn gửi sở tài chính
# ======================================================================
#   [1] Form_05 | Công văn | rerank=0.1700
#       Purpose: Giao dịch, trao đổi công việc hành chính
#   [2] Form_05 | Công văn | rerank=0.1700
#       Purpose: Giao dịch, trao đổi công việc hành chính
#   [3] Form_08 | Giấy giới thiệu | rerank=0.0650
#       Purpose: Giới thiệu cán bộ đi công tác
#
# ======================================================================
# [HYBRID - EXAMPLES] Query: soạn thảo công văn gửi sở tài chính
# ======================================================================
#   [1] Form_05 | rerank=0.1039
#       Scenario: Cục Thuế tỉnh Nghệ An đề nghị hộ kinh doanh triển khai sử dụng hóa đơn điện tử khởi tạo từ máy tính tiền trong năm 2025.
#       Preview : BỘ TÀI CHÍNH  **CỤC THUẾ TỈNH NGHỆ AN**  ---  Số: 502/CT-TTHT  V/v: triển khai hóa đơn điện tử khởi tạo từ máy tính tiền đối với hộ, cá nhân kinh doan...
#   [2] Form_08 | rerank=0.0617
#       Scenario: Cục Thuế TP Hải Phòng giới thiệu kiểm tra viên đến kiểm tra thuế doanh nghiệp.
#       Preview : TỔNG CỤC THUẾ  **CỤC THUẾ TP HẢI PHÒNG**  ---  Số: 902/GGT-CTHP  **CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM**  **Độc lập - Tự do - Hạnh phúc**  ---  Hải Phò...
#   [3] Form_04 | rerank=0.0595
#       Scenario: Phòng Tài chính trình Chủ tịch UBND phê duyệt mua sắm.
#       Preview : UBND HUYỆN CỦ CHI  **PHÒNG TÀI CHÍNH - KẾ HOẠCH**  ---  Số: 128/TTr-TCKH  **CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM**  **Độc lập - Tự do - Hạnh phúc**  ---...
#
# ======================================================================
# [HYBRID - FORMS] Query: viết giấy mời họp ban lãnh đạo
# ======================================================================
#   [1] Form_07 | Giấy mời | rerank=0.6150
#       Purpose: Mời họp, hội nghị, hội thảo
#   [2] Form_07 | Giấy mời | rerank=0.6150
#       Purpose: Mời họp, hội nghị, hội thảo
#   [3] Form_09 | Biên bản | rerank=0.1258
#       Purpose: Ghi chép nội dung cuộc họp/hội nghị
#
# ======================================================================
# [HYBRID - EXAMPLES] Query: viết giấy mời họp ban lãnh đạo
# ======================================================================
#   [1] Form_07 | rerank=0.4763
#       Scenario: Sở Văn hóa và Thể thao Hải Phòng mời dự họp tổ chức Lễ hội Hoa Phượng Đỏ năm 2022.
#       Preview : ỦY BAN NHÂN DÂN THÀNH PHỐ HẢI PHÒNG  **SỞ VĂN HÓA VÀ THỂ THAO**  ---  Số: 58/GM-SVHTT  **CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM**  **Độc lập - Tự do - Hạn...
#   [2] Form_07 | rerank=0.3127
#       Scenario: UBND tỉnh Quảng Nam mời dự cuộc họp về giải ngân vốn đầu tư công năm 2024.
#       Preview : ỦY BAN NHÂN DÂN TỈNH QUẢNG NAM  **ỦY BAN NHÂN DÂN TỈNH QUẢNG NAM**  ---  Số: 87/GM-UBND  **CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM**  **Độc lập - Tự do - H...
#   [3] Form_07 | rerank=0.2834
#       Scenario: Sở Nông nghiệp và PTNT Nghệ An mời họp bàn giải pháp phòng chống dịch bệnh trên đàn gia súc.
#       Preview : ỦY BAN NHÂN DÂN TỈNH NGHỆ AN  **SỞ NÔNG NGHIỆP VÀ PHÁT TRIỂN NÔNG THÔN**  ---  Số: 96/GM-SNNPTNT  **CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM**  **Độc lập - ...
#
# ======================================================================
# [HYBRID - FORMS] Query: làm tờ trình đề nghị phê duyệt dự án
# ======================================================================
#   [1] Form_08 | Giấy giới thiệu | rerank=0.0118
#       Purpose: Giới thiệu cán bộ đi công tác
#   [2] Form_08 | Giấy giới thiệu | rerank=0.0118
#       Purpose: Giới thiệu cán bộ đi công tác
#   [3] Form_05 | Công văn | rerank=0.0076
#       Purpose: Giao dịch, trao đổi công việc hành chính
#
# ======================================================================
# [HYBRID - EXAMPLES] Query: làm tờ trình đề nghị phê duyệt dự án
# ======================================================================
#   [1] Form_04 | rerank=0.4594
#       Scenario: Phòng Tài chính trình Chủ tịch UBND phê duyệt mua sắm.
#       Preview : UBND HUYỆN CỦ CHI  **PHÒNG TÀI CHÍNH - KẾ HOẠCH**  ---  Số: 128/TTr-TCKH  **CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM**  **Độc lập - Tự do - Hạnh phúc**  ---...
#   [2] Form_04 | rerank=0.4594
#       Scenario: Phòng Tài chính trình Chủ tịch UBND phê duyệt mua sắm.
#       Preview : UBND HUYỆN CỦ CHI  **PHÒNG TÀI CHÍNH - KẾ HOẠCH**  ---  Số: 128/TTr-TCKH  **CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM**  **Độc lập - Tự do - Hạnh phúc**  ---...
#   [3] Form_06 | rerank=0.1822
#       Scenario: Thủ tướng Chính phủ chỉ đạo tháo gỡ khó khăn cho thị trường bất động sản.
#       Preview : CHÍNH PHỦ  **THỦ TƯỚNG CHÍNH PHỦ**  ---  Số: 1164/CĐ-TTg  **CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM**  **Độc lập - Tự do - Hạnh phúc**  ---  Hà Nội, ngày 1...
#
# ======================================================================
# [HYBRID - FORMS] Query: giấy giới thiệu cán bộ đi công tác
# ======================================================================
#   [1] Form_08 | Giấy giới thiệu | rerank=0.7387
#       Purpose: Giới thiệu cán bộ đi công tác
#   [2] Form_08 | Giấy giới thiệu | rerank=0.7387
#       Purpose: Giới thiệu cán bộ đi công tác
#   [3] Form_07 | Giấy mời | rerank=0.1494
#       Purpose: Mời họp, hội nghị, hội thảo
#
# ======================================================================
# [HYBRID - EXAMPLES] Query: giấy giới thiệu cán bộ đi công tác
# ======================================================================
#   [1] Form_08 | rerank=0.7355
#       Scenario: UBND Tỉnh Bình Dương giới thiệu Phó Chánh văn phòng đến làm việc tại Bộ Kế hoạch Đầu tư.
#       Preview : TỈNH ỦY BÌNH DƯƠNG  **ỦY BAN NHÂN DÂN**  ---  Số: 205/GGT-UBND  **CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM**  **Độc lập - Tự do - Hạnh phúc**  ---  Bình Dươ...
#   [2] Form_08 | rerank=0.7355
#       Scenario: UBND Tỉnh Bình Dương giới thiệu Phó Chánh văn phòng đến làm việc tại Bộ Kế hoạch Đầu tư.
#       Preview : TỈNH ỦY BÌNH DƯƠNG  **ỦY BAN NHÂN DÂN**  ---  Số: 205/GGT-UBND  **CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM**  **Độc lập - Tự do - Hạnh phúc**  ---  Bình Dươ...
#   [3] Form_08 | rerank=0.7240
#       Scenario: Sở Nông nghiệp và PTNT Đồng Tháp giới thiệu cán bộ đi kiểm tra sâu bệnh.
#       Preview : UBND TỈNH ĐỒNG THÁP  **SỞ NÔNG NGHIỆP VÀ PTNT**  ---  Số: 210/GGT-SNN  **CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM**  **Độc lập - Tự do - Hạnh phúc**  ---  Đ...
#
# ======================================================================
# [HYBRID - FORMS] Query: quyết định bổ nhiệm trưởng phòng
# ======================================================================
#   [1] Form_02 | Quyết định | rerank=0.2207
#       Purpose: Quy định trực tiếp (cá biệt)
#   [2] Form_02 | Quyết định | rerank=0.2207
#       Purpose: Quy định trực tiếp (cá biệt)
#   [3] Form_03 | Quyết định | rerank=0.2188
#       Purpose: Ban hành hoặc phê duyệt văn bản kèm theo
#
# ======================================================================
# [HYBRID - EXAMPLES] Query: quyết định bổ nhiệm trưởng phòng
# ======================================================================
#   [1] Form_02 | rerank=0.7965
#       Scenario: Bộ Tài chính bổ nhiệm Vụ trưởng Vụ Chính sách Thuế.
#       Preview : CHÍNH PHỦ  **BỘ TÀI CHÍNH**  ---  Số: 543/QĐ-BTC  **CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM**  **Độc lập - Tự do - Hạnh phúc**  ---  Hà Nội, ngày 15 tháng ...
#   [2] Form_02 | rerank=0.7965
#       Scenario: Bộ Tài chính bổ nhiệm Vụ trưởng Vụ Chính sách Thuế.
#       Preview : CHÍNH PHỦ  **BỘ TÀI CHÍNH**  ---  Số: 543/QĐ-BTC  **CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM**  **Độc lập - Tự do - Hạnh phúc**  ---  Hà Nội, ngày 15 tháng ...
#   [3] Form_02 | rerank=0.4581
#       Scenario: Bệnh viện Chợ Rẫy cử bác sĩ đi học tập chuyên sâu tại Nhật Bản.
#       Preview : BỘ Y TẾ  **BỆNH VIỆN CHỢ RẪY**  ---  Số: 1456/QĐ-BVCR  **CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM**  **Độc lập - Tự do - Hạnh phúc**  ---  TP. Hồ Chí Minh, ...
#
# ======================================================================
# [HYBRID - FORMS] Query: báo cáo tình hình thực hiện nhiệm vụ
# ======================================================================
#   [1] Form_08 | Giấy giới thiệu | rerank=0.0661
#       Purpose: Giới thiệu cán bộ đi công tác
#   [2] Form_08 | Giấy giới thiệu | rerank=0.0661
#       Purpose: Giới thiệu cán bộ đi công tác
#   [3] Form_05 | Công văn | rerank=0.0243
#       Purpose: Giao dịch, trao đổi công việc hành chính
#
# ======================================================================
# [HYBRID - EXAMPLES] Query: báo cáo tình hình thực hiện nhiệm vụ
# ======================================================================
#   [1] Form_04 | rerank=0.9434
#       Scenario: UBND phường Bến Nghé báo cáo kinh tế xã hội quý I.
#       Preview : UBND QUẬN 1  **UBND PHƯỜNG BẾN NGHÉ**  ---  Số: 34/BC-UBND  **CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM**  **Độc lập - Tự do - Hạnh phúc**  ---  TP. Hồ Chí M...
#   [2] Form_04 | rerank=0.9434
#       Scenario: UBND phường Bến Nghé báo cáo kinh tế xã hội quý I.
#       Preview : UBND QUẬN 1  **UBND PHƯỜNG BẾN NGHÉ**  ---  Số: 34/BC-UBND  **CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM**  **Độc lập - Tự do - Hạnh phúc**  ---  TP. Hồ Chí M...
#   [3] Form_04 | rerank=0.6856
#       Scenario: Công an Thành phố xây dựng phương án đảm bảo an ninh trật tự Tết.
#       Preview : BỘ CÔNG AN  **CÔNG AN THÀNH PHỐ CẦN THƠ**  ---  Số: 12/PA-CATP  **CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM**  **Độc lập - Tự do - Hạnh phúc**  ---  Cần Thơ,...

# %% [markdown]
# ## 11. Test với Metadata Filter

# %%
# ============================================================
# TEST FILTER — lọc theo loại văn bản hoặc số hiệu
# ============================================================

filter_tests = [
    {
        "query" : "điều kiện kinh doanh dịch vụ logistics",
        "where" : {"type_normalized": "NGHỊ ĐỊNH"},
        "desc"  : "Chỉ tìm trong NGHỊ ĐỊNH",
    },
    {
        "query" : "quyền của người lao động",
        "where" : {"type_normalized": "LUẬT"},
        "desc"  : "Chỉ tìm trong LUẬT",
    }
]

for test in filter_tests:
    print(f"\n>>> Filter: {test['desc']}")
    results = retriever_legal.retrieve(
        test["query"],
        where=test["where"],
        use_reranker=True,
    )
    print_legal_results(results, test["query"], mode=f"hybrid+filter")
# Out:
# >>> Filter: Chỉ tìm trong NGHỊ ĐỊNH
#
# ======================================================================
# [HYBRID+FILTER] Query: điều kiện kinh doanh dịch vụ logistics
# ======================================================================
#
#   [1] 163/2017/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 4. Điều kiện kinh doanh dịch vụ logistics
#       🎯 rerank=0.9995 | rrf=0.01613 | bm25=0.00 | dense_dist=0.0642
#       📝 [Điều 4. Điều kiện kinh doanh dịch vụ logistics] 1. Thương nhân kinh doanh các dịch vụ cụ thể thuộc dịch vụ logistics quy định tại Điều 3 Nghị định này phải đáp ứng các điều kiện đầu tư, kinh doanh th...
#
#   [2] 163/2017/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 4. Điều kiện kinh doanh dịch vụ logistics
#       🎯 rerank=0.9995 | rrf=0.01562 | bm25=23.78 | dense_dist=1.0000
#       📝 [Điều 4. Điều kiện kinh doanh dịch vụ logistics] 1. Thương nhân kinh doanh các dịch vụ cụ thể thuộc dịch vụ logistics quy định tại Điều 3 Nghị định này phải đáp ứng các điều kiện đầu tư, kinh doanh th...
#
#   [3] 36/2005/QH11 | LUẬT
#       📌 Điều 234. Điều kiện kinh doanh dịch vụ logistics
#       🎯 rerank=0.9994 | rrf=0.01639 | bm25=27.71 | dense_dist=1.0000
#       📝 Điều 234. Điều kiện kinh doanh dịch vụ logistics 1. Thương nhân kinh doanh dịch vụ logistics là doanh nghiệp có đủ điều kiện kinh doanh dịch vụ logistics theo quy định của pháp luật. 2. Chính phủ quy ...
#
#   [4] 140/2007/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 5. Điều kiện kinh doanh đối với thương nhân kinh doanh các dịch vụ lô-gi-stíc chủ yếu
#       🎯 rerank=0.9981 | rrf=0.01562 | bm25=0.00 | dense_dist=0.0671
#       📝 Điều 5. Điều kiện kinh doanh đối với thương nhân kinh doanh các dịch vụ lô-gi-stíc chủ yếu Thương nhân kinh doanh dịch vụ lô-gi-stíc chủ yếu theo quy định tại khoản 1 Điều 4 Nghị định này phải đáp ứng...
#
#   [5] 140/2007/NĐ-CP | NGHỊ ĐỊNH
#       📌 Điều 7. Điều kiện kinh doanh đối với thương nhân kinh doanh các dịch vụ lô-gi-stíc liên quan khác
#       🎯 rerank=0.9979 | rrf=0.01515 | bm25=0.00 | dense_dist=0.0752
#       📝 Điều 7. Điều kiện kinh doanh đối với thương nhân kinh doanh các dịch vụ lô-gi-stíc liên quan khác Thương nhân kinh doanh dịch vụ lô-gi-stíc liên quan khác theo quy định tại khoản 3 Điều 4 Nghị định nà...
#
#   ⏱  Latency: 16120.4ms
#
# >>> Filter: Chỉ tìm trong LUẬT
#
# ======================================================================
# [HYBRID+FILTER] Query: quyền của người lao động
# ======================================================================
#
#   [1] 45/2019/QH14 | LUẬT
#       📌 Điều 5. Quyền và nghĩa vụ của người lao động
#       🎯 rerank=0.9993 | rrf=0.01639 | bm25=0.00 | dense_dist=0.0820
#       📝 Điều 5. Quyền và nghĩa vụ của người lao động 1. Người lao động có các quyền sau đây: a) Làm việc; tự do lựa chọn việc làm, nơi làm việc, nghề nghiệp, học nghề, nâng cao trình độ nghề nghiệp; không bị ...
#
#   [2] 10/2012/QH13 | LUẬT
#       📌 Điều 5. Quyền và nghĩa vụ của người lao động
#       🎯 rerank=0.9993 | rrf=0.01613 | bm25=0.00 | dense_dist=0.0821
#       📝 Điều 5. Quyền và nghĩa vụ của người lao động 1. Người lao động có các quyền sau đây: a) Làm việc, tự do lựa chọn việc làm, nghề nghiệp, học nghề, nâng cao trình độ nghề nghiệp và không bị phân biệt đố...
#
#   [3] 45/2019/QH14 | LUẬT
#       📌 Điều 6. Quyền và nghĩa vụ của người sử dụng lao động
#       🎯 rerank=0.9967 | rrf=0.01429 | bm25=0.00 | dense_dist=0.0941
#       📝 Điều 6. Quyền và nghĩa vụ của người sử dụng lao động 1. Người sử dụng lao động có các quyền sau đây: a) Tuyển dụng, bố trí, quản lý, điều hành, giám sát lao động; khen thưởng và xử lý vi phạm kỷ luật ...
#
#   [4] 35-L/CTN | LUẬT
#       📌 Điều 7.
#       🎯 rerank=0.9938 | rrf=0.01538 | bm25=0.00 | dense_dist=0.0865
#       📝 Điều 7. 1- Người lao động được trả lương trên cơ sở thoả thuận với người sử dụng lao động nhưng không thấp hơn mức lương tối thiểu do Nhà nước quy định và theo năng suất, chất lượng, hiệu quả công việ...
#
#   [5] 33/2005/QH11 | LUẬT
#       📌 Điều 49. Quyền lao động
#       🎯 rerank=0.9935 | rrf=0.01515 | bm25=0.00 | dense_dist=0.0873
#       📝 Điều 49. Quyền lao động Cá nhân có quyền lao động. Mọi người đều có quyền làm việc, tự do lựa chọn việc làm, nghề nghiệp, không bị phân biệt đối xử về dân tộc, giới tính, thành phần xã hội, tín ngưỡng...
#
#   ⏱  Latency: 6689.1ms

# %% [markdown]
# ## 12. Benchmark: Hybrid vs Semantic-Only

# %%
# ============================================================
# BENCHMARK — So sánh chất lượng trước/sau hybrid
# Dùng BM25 score > 0 ở top-1 làm tín hiệu keyword match
# ============================================================

benchmark_queries = [
    "quy dinh ve hoa giai o co so",
    "dieu kien de duoc cap giay phep kinh doanh",
    "trach nhiem cua Bo truong trong ban hanh van ban",
    "xu phat vi pham hanh chinh giao thong duong bo",
    "quyen va nghia vu nguoi su dung dat",
    "thu tuc dang ky kinh doanh ho ca the",
    "chinh sach ho tro nguoi co cong voi cach mang",
    "quy trinh kiem tra chat luong hang hoa xuat nhap khau",
]

print(f"{'Query':<55} {'Semantic top1 doc':^25} {'Hybrid top1 doc':^25}")
print("-" * 110)

for q in benchmark_queries:
    sem = retriever_legal.retrieve_only_semantic(q)
    hyb = retriever_legal.retrieve(q, use_reranker=True)

    sem_doc = sem[0]["metadata"].get("source_doc_no", "?")[:22] if sem else "N/A"
    hyb_doc = hyb[0]["metadata"].get("source_doc_no", "?")[:22] if hyb else "N/A"
    hyb_rerank = hyb[0].get("rerank_score", 0) if hyb else 0
    hyb_bm25   = hyb[0].get("bm25_score", 0)   if hyb else 0

    same = "=" if sem_doc == hyb_doc else "≠"
    print(f"{q[:54]:<55} {sem_doc:<25} {hyb_doc:<25} {same} rerank={hyb_rerank:.3f} bm25={hyb_bm25:.1f}")

print()
print("Chú thích: '≠' = hybrid trả về kết quả khác semantic → kiểm tra xem cái nào đúng hơn")
# Out:
# Query                                                       Semantic top1 doc          Hybrid top1 doc
# --------------------------------------------------------------------------------------------------------------
# quy dinh ve hoa giai o co so                            18/2022/NĐ-CP             18/2022/NĐ-CP             = rerank=0.006 bm25=0.0
# dieu kien de duoc cap giay phep kinh doanh              58 /2006/NQ-HĐND          81/2016/NĐ-CP             ≠ rerank=0.488 bm25=24.8
# trach nhiem cua Bo truong trong ban hanh van ban        90/NQ-CP                  36/2012/NĐ-CP             ≠ rerank=0.961 bm25=34.8
# xu phat vi pham hanh chinh giao thong duong bo          137/2010/NQ-HĐND          16/2003/NĐ-CP             ≠ rerank=0.766 bm25=21.2
# quyen va nghia vu nguoi su dung dat                     56/NQ-HĐND                13/2003/QH11              ≠ rerank=0.674 bm25=20.8
# thu tuc dang ky kinh doanh ho ca the                    58 /2006/NQ-HĐND          109/2004/NĐ-CP            ≠ rerank=0.844 bm25=18.1
# chinh sach ho tro nguoi co cong voi cach mang           9-L/CTN                   10/2022/NQ-HĐND           ≠ rerank=0.785 bm25=37.9
# quy trinh kiem tra chat luong hang hoa xuat nhap khau   365/2015/NQ-HĐND          179/2004/NĐ-CP            ≠ rerank=0.804 bm25=31.3
#
# Chú thích: '≠' = hybrid trả về kết quả khác semantic → kiểm tra xem cái nào đúng hơn

# %% [markdown]
# ## 13. Convenience Functions — Dùng trong RAG Pipeline

# %%
# ============================================================
# PUBLIC API — dùng trong bước tiếp theo (RAG generation)
# ============================================================

def retrieve_legal(
    query: str,
    top_k: int = 5,
    where: Optional[Dict] = None,
    use_reranker: bool = True,
) -> List[Dict]:
    """
    Truy xuất điều khoản pháp luật liên quan.
    
    Example:
        results = retrieve_legal("điều kiện thành lập doanh nghiệp")
        results = retrieve_legal("quy định", where={"type_normalized": "NGHỊ ĐỊNH"})
    """
    retriever_legal.final_top_k = top_k
    return retriever_legal.retrieve(query, where=where, use_reranker=use_reranker)


def retrieve_forms(
    query: str,
    top_k: int = 3,
    use_reranker: bool = True,
) -> List[Dict]:
    """
    Truy xuất biểu mẫu hành chính phù hợp.
    
    Example:
        results = retrieve_forms("soạn thảo công văn xin phép")
    """
    retriever_forms.final_top_k = top_k
    return retriever_forms.retrieve(query, use_reranker=use_reranker)


def retrieve_examples(
    query: str,
    top_k: int = 3,
    form_id: Optional[str] = None,
    use_reranker: bool = True,
) -> List[Dict]:
    """
    Truy xuất ví dụ văn bản tương tự (few-shot).
    
    Example:
        results = retrieve_examples("giấy mời họp", form_id="Form_07")
    """
    retriever_examples.final_top_k = top_k
    where = {"form_id": form_id} if form_id else None
    return retriever_examples.retrieve(query, where=where, use_reranker=use_reranker)


def retrieve_all(
    query: str,
    legal_top_k: int = 5,
    forms_top_k: int = 3,
    examples_top_k: int = 3,
    legal_filter: Optional[Dict] = None,
) -> Dict[str, List[Dict]]:
    """
    Chạy cả 3 retrievers cùng lúc. Dùng trong RAG pipeline.
    
    Returns:
        {"legal": [...], "forms": [...], "examples": [...]}
    """
    return {
        "legal"   : retrieve_legal(query, top_k=legal_top_k, where=legal_filter),
        "forms"   : retrieve_forms(query, top_k=forms_top_k),
        "examples": retrieve_examples(query, top_k=examples_top_k),
    }


# ── Quick demo ───────────────────────────────────────────────
print("Demo: retrieve_all()")
demo_query = "soạn thảo quyết định bổ nhiệm cán bộ"
all_results = retrieve_all(demo_query)

print(f"\nQuery: '{demo_query}'")
print(f"  Legal    : {len(all_results['legal'])} kết quả")
print(f"  Forms    : {len(all_results['forms'])} kết quả")
print(f"  Examples : {len(all_results['examples'])} kết quả")

print("\nTop legal result:")
if all_results["legal"]:
    r = all_results["legal"][0]
    print(f"  {r['metadata'].get('source_doc_no','?')} | {r['metadata'].get('article','')}")
    print(f"  rerank={r['rerank_score']:.4f} | {r['text']}...")
# Out:
# Demo: retrieve_all()
#
# Query: 'soạn thảo quyết định bổ nhiệm cán bộ'
#   Legal    : 5 kết quả
#   Forms    : 3 kết quả
#   Examples : 3 kết quả
#
# Top legal result:
#   138/2020/NĐ-CP | Điều 46. Trình tự, thủ tục bổ nhiệm công chức giữ chức vụ lãnh đạo, quản lý thuộc thẩm quyền quản lý của Bộ, ngành, địa phương
#   rerank=0.7447 | [Điều 46. Trình tự, thủ tục bổ nhiệm công chức giữ chức vụ lãnh đạo, quản lý thuộc thẩm quyền quản lý của Bộ, ngành, địa phương]
# kín). Nguyên tắc lựa chọn: Người đạt số phiếu cao nhất, đạt tỷ lệ trên 50% tính trên tổng số thành viên tập thể lãnh đạo giới thiệu thì được lựa chọn đề nghị bổ nhiệm. Trường hợp có 02 người có số phiếu ngang nhau (đạt tỷ lệ 50%) thì lựa chọn nhân sự do người đứng đầu giới thiệu để đề nghị bổ nhiệm; đồng thời báo cáo đầy đủ các ý kiến khác nhau để cấp có thẩm quyền xem xét, quyết định. Phiếu biểu quyết nhân sự bổ nhiệm do Ban tổ chức hội nghị phát hành, có đóng dấu treo của cơ quan, tổ chức. Kết quả kiểm phiếu được ghi thành biên bản. Ra quyết định bổ nhiệm theo thẩm quyền hoặc trình cơ quan có thẩm quyền xem xét quyết định. 3. Thực hiện quy trình bổ nhiệm đối với nguồn nhân sự từ nơi khác: a) Trường hợp nhân sự do cơ quan, tổ chức đề xuất thì tập thể lãnh đạo cơ quan, tổ chức thảo luận, thống nhất về chủ trương và tiến hành một số công việc sau: Gặp nhân sự được đề nghị bổ nhiệm để trao đổi ý kiến về yêu cầu nhiệm vụ công tác. Trao đổi ý kiến với tập thể lãnh đạo và cấp ủy cơ quan, tổ chức nơi người được đề nghị bổ nhiệm đang công tác về chủ trương điều động; lấy nhận xét, đánh giá của tập thể lãnh đạo và cấp ủy cơ quan, tổ chức đối với nhân sự; nghiên cứu hồ sơ, xác minh lý lịch. Thảo luận, nhận xét, đánh giá và biểu quyết nhân sự bằng phiếu kín. Nhân sự được đề nghị bổ nhiệm phải đạt tỷ lệ trên 50% tổng số thành viên tập thể lãnh đạo đồng ý; trường hợp nhân sự đạt tỷ lệ 50% thì do người đứng đầu quyết định; đồng thời báo cáo đầy đủ các ý kiến khác nhau để cấp có thẩm quyền xem xét, quyết định. Ra quyết định bổ nhiệm theo thẩm quyền hoặc trình cơ quan có thẩm quyền xem xét quyết định. b) Trường hợp nhân sự do cơ quan cấp trên có thẩm quyền dự kiến điều động, bổ nhiệm từ nguồn nhân sự ngoài cơ quan, tổ chức thì cơ quan tham mưu về tổ chức cán bộ của cơ...

# %% [markdown]
# ---
#
# ## Summary
#
# | Component | Model / Library | Mô tả |
# |---|---|---|
# | **BM25** | `rank_bm25.BM25Okapi` | Keyword match, normalize không dấu, persist pkl |
# | **Dense** | `multilingual-e5-large-instruct` | Asymmetric semantic search, L2-normalized |
# | **Fusion** | Reciprocal Rank Fusion (k=60) | Merge BM25 + dense ranked lists |
# | **Reranker** | `BAAI/bge-reranker-v2-m3` | Cross-encoder, multilingual, tiếng Việt tốt |
#
# **Bước tiếp theo:** Dùng `retrieve_all()` trong RAG generation pipeline.
